# %%
import pickle
import os
import numpy as np
from lmfit import  Model, Parameters
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from ANEMO import read_edf
from ANEMO import ANEMO

# %%
sujet = ['AM','BMC','CS','DC','FM','IP','LB','OP','RS','SR','TN','YK']

# %%
import glob
liste = []
for fname in glob.glob('data/*pkl'):
    a = fname.split('/')[1].split('.')[0].split('_')
    liste.append(a)

BET = {}
for x in range(len(liste)) :
    if liste[x][0]=='pari' and liste[x][1] in sujet:
        a = 'data/%s_%s_%s_%s.pkl'%(liste[x][0], liste[x][1],liste[x][2],liste[x][3])
        with open(a, 'rb') as fichier :
            b = pickle.load(fichier, encoding='latin1')
            BET[liste[x][1]] = b

# %%
fig1, ax1 = plt.subplots(1,1, figsize=[15, 15/2])
N_cols = 4
fig, ax = plt.subplots(int(len(sujet)/N_cols), N_cols, figsize=[15, 15/2])

scaling_sujet = {}
scaling_full = []

a, b = 0, 0
bet_full = []
for i, x in enumerate(sujet) :
    ax[b][a].set_title(x)
    
    bet = []
    for block in range(BET[x]['N_blocks']) :
        bet.extend((BET[x]['results'][:,block]+1)/2)
    bet_full.extend(bet)
    scaling_sujet[x] = np.sort(bet)
    
    ax[b][a].plot(scaling_sujet[x], np.linspace(0, 1, len(scaling_sujet[x])), c='k')
    # a = i // N_cols
    # b = i % N_cols
    
    a = a+1
    if a > 3 :
        a = 0
        b = b+1

scaling_full = np.sort(bet_full)

ax1.set_title('Full')
ax1.plot(scaling_full, np.linspace(0,1,len(scaling_full)), c='k') 

fig.tight_layout()
fig1.tight_layout()

plt.show()

# %%
np.interp?
# Out:
# Signature: np.interp(x, xp, fp, left=None, right=None, period=None)
# Docstring:
# One-dimensional linear interpolation.
#
# Returns the one-dimensional piecewise linear interpolant to a function
# with given discrete data points (`xp`, `fp`), evaluated at `x`.
#
# Parameters
# ----------
# x : array_like
#     The x-coordinates at which to evaluate the interpolated values.
#
# xp : 1-D sequence of floats
#     The x-coordinates of the data points, must be increasing if argument
#     `period` is not specified. Otherwise, `xp` is internally sorted after
#     normalizing the periodic boundaries with ``xp = xp % period``.
#
# fp : 1-D sequence of float or complex
#     The y-coordinates of the data points, same length as `xp`.
#
# left : optional float or complex corresponding to fp
#     Value to return for `x < xp[0]`, default is `fp[0]`.
#
# right : optional float or complex corresponding to fp
#     Value to return for `x > xp[-1]`, default is `fp[-1]`.
#
# period : None or float, optional
#     A period for the x-coordinates. This parameter allows the proper
#     interpolation of angular x-coordinates. Parameters `left` and `right`
#     are ignored if `period` is specified.
#
#     .. versionadded:: 1.10.0
#
# Returns
# -------
# y : float or complex (corresponding to fp) or ndarray
#     The interpolated values, same shape as `x`.
#
# Raises
# ------
# ValueError
#     If `xp` and `fp` have different length
#     If `xp` or `fp` are not 1-D sequences
#     If `period == 0`
#
# Notes
# -----
# Does not check that the x-coordinate sequence `xp` is increasing.
# If `xp` is not increasing, the results are nonsense.
# A simple check for increasing is::
#
#     np.all(np.diff(xp) > 0)
#
# Examples
# --------
# >>> xp = [1, 2, 3]
# >>> fp = [3, 2, 0]
# >>> np.interp(2.5, xp, fp)
# 1.0
# >>> np.interp([0, 1, 1.5, 2.72, 3.14], xp, fp)
# array([ 3. ,  3. ,  2.5 ,  0.56,  0. ])
# >>> UNDEF = -99.0
# >>> np.interp(3.14, xp, fp, right=UNDEF)
# -99.0
#
# Plot an interpolant to the sine function:
#
# >>> x = np.linspace(0, 2*np.pi, 10)
# >>> y = np.sin(x)
# >>> xvals = np.linspace(0, 2*np.pi, 50)
# >>> yinterp = np.interp(xvals, x, y)
# >>> import matplotlib.pyplot as plt
# >>> plt.plot(x, y, 'o')
# [<matplotlib.lines.Line2D object at 0x...>]
# >>> plt.plot(xvals, yinterp, '-x')
# [<matplotlib.lines.Line2D object at 0x...>]
# >>> plt.show()
#
# Interpolation with periodic x-coordinates:
#
# >>> x = [-180, -170, -185, 185, -10, -5, 0, 365]
# >>> xp = [190, -190, 350, -350]
# >>> fp = [5, 10, 3, 4]
# >>> np.interp(x, xp, fp, period=360)
# array([7.5, 5., 8.75, 6.25, 3., 3.25, 3.5, 3.75])
#
# Complex interpolation:
#
# >>> x = [1.5, 4.0]
# >>> xp = [2,3,5]
# >>> fp = [1.0j, 0, 2+3j]
# >>> np.interp(x, xp, fp)
# array([ 0.+1.j ,  1.+1.5j])
# File:      /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py
# Type:      function

# %%
c = ['k', 'grey', 'r']

new_proba_full = np.linspace(0,1,len(scaling_full))

for x in sujet :
    
    fig, ax = plt.subplots(3, 1, figsize=[15,15*1/2]) 
    
    new_proba_sujet = np.linspace(0, 1, len(scaling_sujet[x]))
    
    print(x)
    
    a = 0
    for block in range(3) :
        new_bet_sujet = []
        new_bet_full = []
        
        bet = (BET[x]['results'][:,block]+1)/2
        
        proba = BET[x]['p'][:,block, 1]
        
        for trial in range(len(bet)) :
            p = []
            for t in range(len(scaling_sujet[x])) :
                if scaling_sujet[x][t] == bet[trial] :
                    p.append(new_proba_sujet[t])
            new_bet_sujet.append(np.mean(p))
            
            p = []
            for t in range(len(scaling_full)) :
                if scaling_full[t] == bet[trial] :
                    p.append(new_proba_full[t])
            new_bet_full.append(np.mean(p))
        
        print('\nblock', block)
        print('bet : min = %0.3f -- max = %0.3f'%(min(bet), max(bet)))
        print('new_bet_sujet : min = %0.3f -- max = %0.3f'%(min(new_bet_sujet), max(new_bet_sujet)),
              'new_bet_full : min = %0.3f -- max = %0.3f'%(min(new_bet_full),max(new_bet_full)),
              sep='    ')
        
        
        ax[a].fill_between(range(len(proba)), np.zeros_like(proba), proba,
                                  lw=.5, alpha=0.2, facecolor='k', step='pre')

        
        ax[a].set_title(block)
        
        ax[a].plot(bet, c=c[block])
        ax[a].plot(new_bet_sujet, c=c[block], ls=':')
        ax[a].plot(new_bet_full, c=c[block], ls='--')
        
        a=a+1
    fig.tight_layout()
    plt.show()
# Out:
# AM
#
# block 0
# bet : min = 0.010 -- max = 0.730
# new_bet_sujet : min = 0.008 -- max = 0.722    new_bet_full : min = 0.141 -- max = 0.671
#
# block 1
# bet : min = 0.010 -- max = 0.965
# new_bet_sujet : min = 0.008 -- max = 0.878    new_bet_full : min = 0.141 -- max = 0.806
#
# block 2
# bet : min = 0.020 -- max = 0.995
# new_bet_sujet : min = 0.053 -- max = 0.995    new_bet_full : min = 0.155 -- max = 0.862
# BMC
#
# block 0
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.103 -- max = 0.927    new_bet_full : min = 0.064 -- max = 0.935
#
# block 1
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.103 -- max = 0.927    new_bet_full : min = 0.064 -- max = 0.935
#
# block 2
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.103 -- max = 0.927    new_bet_full : min = 0.064 -- max = 0.935
# CS
#
# block 0
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.037 -- max = 0.972    new_bet_full : min = 0.064 -- max = 0.935
#
# block 1
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.037 -- max = 0.972    new_bet_full : min = 0.064 -- max = 0.935
#
# block 2
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.037 -- max = 0.972    new_bet_full : min = 0.064 -- max = 0.935
# DC
#
# block 0
# bet : min = 0.015 -- max = 0.965
# new_bet_sujet : min = 0.017 -- max = 0.962    new_bet_full : min = 0.146 -- max = 0.806
#
# block 1
# bet : min = 0.055 -- max = 1.000
# new_bet_sujet : min = 0.043 -- max = 0.999    new_bet_full : min = 0.209 -- max = 0.935
#
# block 2
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.008 -- max = 0.999    new_bet_full : min = 0.064 -- max = 0.935
# FM
#
# block 0
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.087 -- max = 0.897    new_bet_full : min = 0.064 -- max = 0.935
#
# block 1
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.087 -- max = 0.897    new_bet_full : min = 0.064 -- max = 0.935
#
# block 2
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.087 -- max = 0.897    new_bet_full : min = 0.064 -- max = 0.935
# IP
#
# block 0
# bet : min = 0.000 -- max = 0.860
# new_bet_sujet : min = 0.052 -- max = 0.887    new_bet_full : min = 0.064 -- max = 0.742
#
# block 1
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.052 -- max = 0.984    new_bet_full : min = 0.064 -- max = 0.935
#
# block 2
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.052 -- max = 0.984    new_bet_full : min = 0.064 -- max = 0.935
# LB
#
# block 0
# bet : min = 0.005 -- max = 0.990
# new_bet_sujet : min = 0.003 -- max = 0.931    new_bet_full : min = 0.134 -- max = 0.849
#
# block 1
# bet : min = 0.005 -- max = 0.990
# new_bet_sujet : min = 0.003 -- max = 0.931    new_bet_full : min = 0.134 -- max = 0.849
#
# block 2
# bet : min = 0.010 -- max = 1.000
# new_bet_sujet : min = 0.011 -- max = 0.992    new_bet_full : min = 0.141 -- max = 0.935
# OP
#
# block 0
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.100 -- max = 0.866    new_bet_full : min = 0.064 -- max = 0.935
#
# block 1
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.100 -- max = 0.866    new_bet_full : min = 0.064 -- max = 0.935
#
# block 2
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.100 -- max = 0.866    new_bet_full : min = 0.064 -- max = 0.935
# RS
#
# block 0
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.014 -- max = 0.992    new_bet_full : min = 0.064 -- max = 0.935
#
# block 1
# bet : min = 0.015 -- max = 0.985
# new_bet_sujet : min = 0.068 -- max = 0.918    new_bet_full : min = 0.146 -- max = 0.840
#
# block 2
# bet : min = 0.015 -- max = 0.990
# new_bet_sujet : min = 0.068 -- max = 0.962    new_bet_full : min = 0.146 -- max = 0.849
# SR
#
# block 0
# bet : min = 0.000 -- max = 0.880
# new_bet_sujet : min = 0.061 -- max = 0.813    new_bet_full : min = 0.064 -- max = 0.752
#
# block 1
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.061 -- max = 0.949    new_bet_full : min = 0.064 -- max = 0.935
#
# block 2
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.061 -- max = 0.949    new_bet_full : min = 0.064 -- max = 0.935
# TN
#
# block 0
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.098 -- max = 0.867    new_bet_full : min = 0.064 -- max = 0.935
#
# block 1
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.098 -- max = 0.867    new_bet_full : min = 0.064 -- max = 0.935
#
# block 2
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.098 -- max = 0.867    new_bet_full : min = 0.064 -- max = 0.935
# YK
#
# block 0
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.208 -- max = 0.783    new_bet_full : min = 0.064 -- max = 0.935
#
# block 1
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.208 -- max = 0.783    new_bet_full : min = 0.064 -- max = 0.935
#
# block 2
# bet : min = 0.000 -- max = 1.000
# new_bet_sujet : min = 0.208 -- max = 0.783    new_bet_full : min = 0.064 -- max = 0.935
