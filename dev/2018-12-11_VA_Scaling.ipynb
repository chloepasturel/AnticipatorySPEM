# %%
import pickle
import os
from ANEMO import read_edf
from ANEMO import ANEMO
import numpy as np
from lmfit import  Model, Parameters
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mode = 'enregistrement'
from aSPEM import Analysis
e = Analysis(observer='AM', mode=mode)

# %%
Full = e.Full_list(modes_bcp=None)

# %%
sujet = ['AM','BMC','CS','DC','FM','IP','LB','OP','RS','SR','TN','YK']

# %%
fig1, ax1 = plt.subplots(1,1, figsize=[15, 15/2])
fig, ax = plt.subplots(int(len(sujet)/4), 4, figsize=[15, 15/2])

scaling_sujet = {}
scaling_full = []

a, b = 0, 0
va_full = []
for x in sujet :
    ax[b][a].set_title(x)

    va_full.extend(list(Full['va'][Full.sujet==x]))
    scaling_sujet[x] = np.sort(list(Full['va'][Full.sujet==x]))
    
    ax[b][a].plot(scaling_sujet[x], np.linspace(0,1,len(scaling_sujet[x])), c='k')
    a = a+1
    if a > 3 :
        a = 0
        b = b+1

scaling_full = np.sort(va_full)

ax1.set_title('Full')
ax1.plot(scaling_full, np.linspace(0,1,len(scaling_full)), c='k') 

fig.tight_layout()
fig1.tight_layout()

plt.show()

# %%
c = ['k', 'grey', 'r']

new_proba_full = np.linspace(0,1,len(scaling_full))

for x in sujet :
    
    fig, ax = plt.subplots(3, 1, figsize=[15,15*1/2])        
    new_proba_sujet = np.linspace(0, 1, len(scaling_sujet[x]))
    
    print(x)
    
    nb_trial = 0
    a = 0
    for block in range(3) :
        new_va_sujet = []
        new_va_full = []
        
        va = list(Full['va'][Full.sujet==x])
        
        va = va[nb_trial:200+nb_trial*block]
        for trial in range(len(va)) :
            p = []
            for t in range(len(scaling_sujet[x])) :
                if scaling_sujet[x][t] == va[trial] :
                    p.append(new_proba_sujet[t])
            new_va_sujet.append(np.mean(p))
            
            p = []
            for t in range(len(scaling_full)) :
                if scaling_full[t] == va[trial] :
                    p.append(new_proba_full[t])
            new_va_full.append(np.mean(p))
        
        print('\nblock', block)
        print('va : min = %0.3f -- max = %0.3f'%(min(va), max(va)))
        print('new_va_sujet : min = %0.3f -- max = %0.3f'%(min(new_va_sujet), max(new_va_sujet)),
              'new_va_full : min = %0.3f -- max = %0.3f'%(min(new_va_full),max(new_va_full)),
              sep='    ')
        
        ax1 = ax[a].twinx()
        ax1.plot(va, c=c[block])
        
        
        proba = list(Full['proba'][Full.sujet==x])
        proba = proba[nb_trial:200+nb_trial*block]
        ax[a].fill_between(range(len(va)), np.zeros_like(proba), proba,
                                  lw=.5, alpha=0.2, facecolor='k', step='pre')

        
        ax[a].plot(new_va_sujet, c=c[block], ls=':')
        ax[a].plot(new_va_full, c=c[block], ls='--')
        
        ax[a].set_title(block)
        
        a = a+1
        nb_trial = nb_trial+200
    fig.tight_layout()
    plt.show()
# Out:
# AM
#
# block 0
# va : min = -11.929 -- max = 10.480
# new_va_sujet : min = 0.007 -- max = 1.000    new_va_full : min = 0.001 -- max = 0.999
#
# block 1
# va : min = -14.018 -- max = 6.424
# new_va_sujet : min = 0.000 -- max = 0.982    new_va_full : min = 0.000 -- max = 0.980
#
# block 2
# va : min = -10.719 -- max = 10.149
# new_va_sujet : min = 0.017 -- max = 0.998    new_va_full : min = 0.004 -- max = 0.998
# BMC
#
# block 0
# va : min = -10.170 -- max = 5.582
# new_va_sujet : min = 0.002 -- max = 0.982    new_va_full : min = 0.006 -- max = 0.963
#
# block 1
# va : min = -10.371 -- max = 7.200
# new_va_sujet : min = 0.000 -- max = 0.995    new_va_full : min = 0.005 -- max = 0.989
#
# block 2
# va : min = -8.050 -- max = 8.642
# new_va_sujet : min = 0.007 -- max = 1.000    new_va_full : min = 0.019 -- max = 0.995
# CS
#
# block 0
# va : min = -7.836 -- max = 13.410
# new_va_sujet : min = 0.012 -- max = 1.000    new_va_full : min = 0.021 -- max = 1.000
#
# block 1
# va : min = -11.763 -- max = 9.188
# new_va_sujet : min = 0.000 -- max = 0.997    new_va_full : min = 0.002 -- max = 0.997
#
# block 2
# va : min = -5.567 -- max = 9.194
# new_va_sujet : min = 0.047 -- max = 0.998    new_va_full : min = 0.066 -- max = 0.997
# DC
#
# block 0
# va : min = -9.363 -- max = 5.920
# new_va_sujet : min = 0.002 -- max = 0.998    new_va_full : min = 0.009 -- max = 0.970
#
# block 1
# va : min = -11.017 -- max = 5.116
# new_va_sujet : min = 0.000 -- max = 0.988    new_va_full : min = 0.003 -- max = 0.948
#
# block 2
# va : min = -8.073 -- max = 7.058
# new_va_sujet : min = 0.007 -- max = 1.000    new_va_full : min = 0.019 -- max = 0.987
# FM
#
# block 0
# va : min = -11.207 -- max = 5.113
# new_va_sujet : min = 0.000 -- max = 0.998    new_va_full : min = 0.002 -- max = 0.948
#
# block 1
# va : min = -9.805 -- max = 4.747
# new_va_sujet : min = 0.003 -- max = 0.993    new_va_full : min = 0.007 -- max = 0.932
#
# block 2
# va : min = -8.797 -- max = 6.153
# new_va_sujet : min = 0.007 -- max = 1.000    new_va_full : min = 0.012 -- max = 0.975
# IP
#
# block 0
# va : min = -6.804 -- max = 6.434
# new_va_sujet : min = 0.002 -- max = 0.977    new_va_full : min = 0.036 -- max = 0.981
#
# block 1
# va : min = -7.330 -- max = 5.168
# new_va_sujet : min = 0.000 -- max = 0.925    new_va_full : min = 0.028 -- max = 0.950
#
# block 2
# va : min = -4.514 -- max = 10.629
# new_va_sujet : min = 0.035 -- max = 1.000    new_va_full : min = 0.105 -- max = 0.999
# LB
#
# block 0
# va : min = -11.053 -- max = 9.279
# new_va_sujet : min = 0.010 -- max = 0.983    new_va_full : min = 0.002 -- max = 0.997
#
# block 1
# va : min = -14.212 -- max = 13.511
# new_va_sujet : min = 0.000 -- max = 0.998    new_va_full : min = 0.000 -- max = 1.000
#
# block 2
# va : min = -12.032 -- max = 14.187
# new_va_sujet : min = 0.005 -- max = 1.000    new_va_full : min = 0.001 -- max = 1.000
# OP
#
# block 0
# va : min = -7.565 -- max = 8.520
# new_va_sujet : min = 0.002 -- max = 0.998    new_va_full : min = 0.024 -- max = 0.995
#
# block 1
# va : min = -9.457 -- max = 5.896
# new_va_sujet : min = 0.000 -- max = 0.980    new_va_full : min = 0.008 -- max = 0.969
#
# block 2
# va : min = -7.114 -- max = 9.113
# new_va_sujet : min = 0.015 -- max = 1.000    new_va_full : min = 0.032 -- max = 0.997
# RS
#
# block 0
# va : min = -10.270 -- max = 9.951
# new_va_sujet : min = 0.000 -- max = 0.995    new_va_full : min = 0.005 -- max = 0.998
#
# block 1
# va : min = -10.193 -- max = 6.973
# new_va_sujet : min = 0.002 -- max = 0.983    new_va_full : min = 0.006 -- max = 0.986
#
# block 2
# va : min = -8.440 -- max = 15.985
# new_va_sujet : min = 0.005 -- max = 1.000    new_va_full : min = 0.016 -- max = 1.000
# SR
#
# block 0
# va : min = -7.737 -- max = 4.965
# new_va_sujet : min = 0.000 -- max = 0.985    new_va_full : min = 0.022 -- max = 0.943
#
# block 1
# va : min = -7.258 -- max = 7.189
# new_va_sujet : min = 0.003 -- max = 0.998    new_va_full : min = 0.030 -- max = 0.989
#
# block 2
# va : min = -5.242 -- max = 9.110
# new_va_sujet : min = 0.017 -- max = 1.000    new_va_full : min = 0.076 -- max = 0.996
# TN
#
# block 0
# va : min = -3.632 -- max = 4.840
# new_va_sujet : min = 0.025 -- max = 0.975    new_va_full : min = 0.149 -- max = 0.938
#
# block 1
# va : min = -6.514 -- max = 5.380
# new_va_sujet : min = 0.000 -- max = 0.993    new_va_full : min = 0.042 -- max = 0.959
#
# block 2
# va : min = -3.500 -- max = 6.831
# new_va_sujet : min = 0.033 -- max = 1.000    new_va_full : min = 0.157 -- max = 0.984
# YK
#
# block 0
# va : min = -10.526 -- max = 7.289
# new_va_sujet : min = 0.007 -- max = 0.982    new_va_full : min = 0.004 -- max = 0.990
#
# block 1
# va : min = -12.284 -- max = 7.729
# new_va_sujet : min = 0.000 -- max = 0.993    new_va_full : min = 0.001 -- max = 0.991
#
# block 2
# va : min = -10.720 -- max = 9.122
# new_va_sujet : min = 0.003 -- max = 1.000    new_va_full : min = 0.003 -- max = 0.997
