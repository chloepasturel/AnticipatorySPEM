# %%
# %load_ext autoreload
# %autoreload 2
from __future__ import division, print_function, absolute_import
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
# %matplotlib inline

# %%
observers = [ 'AM', 'BMC', 'CS', 'DC', 'FM', 'IP', 'LB', 'OP', 'RS', 'SR', 'TN', 'YK']


for observer in observers : 
    print('Analysing subject', observer)
    mode = 'enregistrement'
    from aSPEM import Analysis
    e = Analysis(observer=observer, mode=mode)
    e.Fit(plot=True, fct_fit='fct_position')
# Out:
# Analysing subject AM
# block, trial =  0 0
# nan
# block, trial =  0 1
# nan
# block, trial =  0 2
# nan
# block, trial =  0 3
# nan
# block, trial =  0 4
# 1386.0
# block, trial =  0 5
# nan
# block, trial =  0 6
# 1128.0
# block, trial =  0 7
# 1085.0
# block, trial =  0 8
# nan
# block, trial =  0 9
# nan
# block, trial =  0 10
# nan
# block, trial =  0 11
# 1008.0
# block, trial =  0 12
# nan
# block, trial =  0 13
# 1146.0
# block, trial =  0 14
# 986.0
# block, trial =  0 15
# 1031.0
# block, trial =  0 16
# nan
# block, trial =  0 17
# nan
# block, trial =  0 18
# nan
# block, trial =  0 19
# nan
# block, trial =  0 20
# 1019.0
# block, trial =  0 21
# 967.0
# block, trial =  0 22
# 1361.0
# block, trial =  0 23
# nan
# block, trial =  0 24
# nan
# block, trial =  0 25
# 1091.0
# block, trial =  0 26
# 1096.0
# block, trial =  0 27
# 1249.0
# block, trial =  0 28
# nan
# block, trial =  0 29
# nan
# block, trial =  0 30
# 1102.0
# block, trial =  0 31
# 1165.0
# block, trial =  0 32
# 1317.0
# block, trial =  0 33
# nan
# block, trial =  0 34
# nan
# block, trial =  0 35
# nan
# block, trial =  0 36
# nan
# block, trial =  0 37
# 936.0
# block, trial =  0 38
# 1382.0
# block, trial =  0 39
# 1423.0
# block, trial =  0 40
# nan
# block, trial =  0 41
# nan
# block, trial =  0 42
# nan
# block, trial =  0 43
# nan
# block, trial =  0 44
# 1125.0
# block, trial =  0 45
# nan
# block, trial =  0 46
# nan
# block, trial =  0 47
# nan
# block, trial =  0 48
# 1148.0
# block, trial =  0 49
# nan
# block, trial =  0 50
# 1055.0
# block, trial =  0 51
# nan
# block, trial =  0 52
# 1388.0
# block, trial =  0 53
# nan
# block, trial =  0 54
# nan
# block, trial =  0 55
# nan
# block, trial =  0 56
# nan
# block, trial =  0 57
# 1002.0
# block, trial =  0 58
# nan
# block, trial =  0 59
# 1158.0
# block, trial =  0 60
# nan
# block, trial =  0 61
# 1207.0
# block, trial =  0 62
# nan
# block, trial =  0 63
# 1073.0
# block, trial =  0 64
# 1362.0
# block, trial =  0 65
# nan
# block, trial =  0 66
# nan
# block, trial =  0 67
# nan
# block, trial =  0 68
# nan
# block, trial =  0 69
# 1330.0
# block, trial =  0 70
# 1189.0
# block, trial =  0 71
# 1075.0
# block, trial =  0 72
# 992.0
# block, trial =  0 73
# 1407.0
# block, trial =  0 74
# 1013.0
# block, trial =  0 75
# 1402.0
# block, trial =  0 76
# 1304.0
# block, trial =  0 77
# nan
# block, trial =  0 78
# nan
# block, trial =  0 79
# 1170.0
# block, trial =  0 80
# nan
# block, trial =  0 81
# 1127.0
# block, trial =  0 82
# nan
# block, trial =  0 83
# nan
# block, trial =  0 84
# 1000.0
# block, trial =  0 85
# 1361.0
# block, trial =  0 86
# 1140.0
# block, trial =  0 87
# nan
# block, trial =  0 88
# nan
# block, trial =  0 89
# 1045.0
# block, trial =  0 90
# nan
# block, trial =  0 91
# 1373.0
# block, trial =  0 92
# nan
# block, trial =  0 93
# 1245.0
# block, trial =  0 94
# nan
# block, trial =  0 95
# 1226.0
# block, trial =  0 96
# nan
# block, trial =  0 97
# nan
# block, trial =  0 98
# 1351.0
# block, trial =  0 99
# nan
# block, trial =  0 100
# 1317.0
# block, trial =  0 101
# nan
# block, trial =  0 102
# 1190.0
# block, trial =  0 103
# nan
# block, trial =  0 104
# nan
# block, trial =  0 105
# 1074.0
# block, trial =  0 106
# 1393.0
# block, trial =  0 107
# nan
# block, trial =  0 108
# 1035.0
# block, trial =  0 109
# nan
# block, trial =  0 110
# 485.0
# block, trial =  0 111
# nan
# block, trial =  0 112
# nan
# block, trial =  0 113
# nan
# block, trial =  0 114
# 1126.0
# block, trial =  0 115
# 983.0
# block, trial =  0 116
# 941.0
# block, trial =  0 117
# 1184.0
# block, trial =  0 118
# nan
# block, trial =  0 119
# nan
# block, trial =  0 120
# nan
# block, trial =  0 121
# nan
# block, trial =  0 122
# nan
# block, trial =  0 123
# 1213.0
# block, trial =  0 124
# 1180.0
# block, trial =  0 125
# nan
# block, trial =  0 126
# nan
# block, trial =  0 127
# nan
# block, trial =  0 128
# nan
# block, trial =  0 129
# nan
# block, trial =  0 130
# nan
# block, trial =  0 131
# 1249.0
# block, trial =  0 132
# nan
# block, trial =  0 133
# nan
# block, trial =  0 134
# nan
# block, trial =  0 135
# 1197.0
# block, trial =  0 136
# 1109.0
# block, trial =  0 137
# 1267.0
# block, trial =  0 138
# nan
# block, trial =  0 139
# 1045.0
# block, trial =  0 140
# nan
# block, trial =  0 141
# nan
# block, trial =  0 142
# 1350.0
# block, trial =  0 143
# 1266.0
# block, trial =  0 144
# nan
# block, trial =  0 145
# nan
# block, trial =  0 146
# nan
# block, trial =  0 147
# 1041.0
# block, trial =  0 148
# nan
# block, trial =  0 149
# nan
# block, trial =  0 150
# nan
# block, trial =  0 151
# 1172.0
# block, trial =  0 152
# 1125.0
# block, trial =  0 153
# nan
# block, trial =  0 154
# nan
# block, trial =  0 155
# 1053.0
# block, trial =  0 156
# 1050.0
# block, trial =  0 157
# 1319.0
# block, trial =  0 158
# 1110.0
# block, trial =  0 159
# 1074.0
# block, trial =  0 160
# nan
# block, trial =  0 161
# 989.0
# block, trial =  0 162
# nan
# block, trial =  0 163
# 1154.0
# block, trial =  0 164
# 1256.0
# block, trial =  0 165
# 1042.0
# block, trial =  0 166
# nan
# block, trial =  0 167
# nan
# block, trial =  0 168
# 1277.0
# block, trial =  0 169
# 1041.0
# block, trial =  0 170
# 1298.0
# block, trial =  0 171
# 1115.0
# block, trial =  0 172
# nan
# block, trial =  0 173
# 1306.0
# block, trial =  0 174
# nan
# block, trial =  0 175
# nan
# block, trial =  0 176
# 1145.0
# block, trial =  0 177
# 1315.0
# block, trial =  0 178
# 1300.0
# block, trial =  0 179
# nan
# block, trial =  0 180
# nan
# block, trial =  0 181
# 1003.0
# block, trial =  0 182
# 1224.0
# block, trial =  0 183
# 1339.0
# block, trial =  0 184
# 1102.0
# block, trial =  0 185
# 1208.0
# block, trial =  0 186
# 1169.0
# block, trial =  0 187
# nan
# block, trial =  0 188
# nan
# block, trial =  0 189
# nan
# block, trial =  0 190
# 1333.0
# block, trial =  0 191
# 1299.0
# block, trial =  0 192
# 1374.0
# block, trial =  0 193
# 1296.0
# block, trial =  0 194
# 1023.0
# block, trial =  0 195
# nan
# block, trial =  0 196
# 1295.0
# block, trial =  0 197
# 1168.0
# block, trial =  0 198
# 1269.0
# block, trial =  0 199
# 1133.0
# block, trial =  1 0
# nan
# block, trial =  1 1
# nan
# block, trial =  1 2
# nan
# block, trial =  1 3
# 1269.0
# block, trial =  1 4
# nan
# block, trial =  1 5
# nan
# block, trial =  1 6
# nan
# block, trial =  1 7
# 1075.0
# block, trial =  1 8
# 1277.0
# block, trial =  1 9
# nan
# block, trial =  1 10
# 1288.0
# block, trial =  1 11
# nan
# block, trial =  1 12
# nan
# block, trial =  1 13
# 958.0
# block, trial =  1 14
# nan
# block, trial =  1 15
# nan
# block, trial =  1 16
# 1151.0
# block, trial =  1 17
# nan
# block, trial =  1 18
# 793.0
# block, trial =  1 19
# 1261.0
# block, trial =  1 20
# nan
# block, trial =  1 21
# nan
# block, trial =  1 22
# nan
# block, trial =  1 23
# nan
# block, trial =  1 24
# nan
# block, trial =  1 25
# 1061.0
# block, trial =  1 26
# 1380.0
# block, trial =  1 27
# 1200.0
# block, trial =  1 28
# nan
# block, trial =  1 29
# nan
# block, trial =  1 30
# nan
# block, trial =  1 31
# 1000.0
# block, trial =  1 32
# 1279.0
# block, trial =  1 33
# nan
# block, trial =  1 34
# 944.0
# block, trial =  1 35
# 1458.0
# block, trial =  1 36
# 1214.0
# block, trial =  1 37
# nan
# block, trial =  1 38
# 1008.0
# block, trial =  1 39
# nan
# block, trial =  1 40
# 1167.0
# block, trial =  1 41
# nan
# block, trial =  1 42
# 1304.0
# block, trial =  1 43
# nan
# block, trial =  1 44
# 1008.0
# block, trial =  1 45
# 1001.0
# block, trial =  1 46
# 1413.0
# block, trial =  1 47
# 1206.0
# block, trial =  1 48
# nan
# block, trial =  1 49
# nan
# block, trial =  1 50
# nan
# block, trial =  1 51
# 1198.0
# block, trial =  1 52
# nan
# block, trial =  1 53
# nan
# block, trial =  1 54
# 998.0
# block, trial =  1 55
# nan
# block, trial =  1 56
# 1166.0
# block, trial =  1 57
# 1268.0
# block, trial =  1 58
# 1121.0
# block, trial =  1 59
# 1049.0
# block, trial =  1 60
# 1132.0
# block, trial =  1 61
# 623.0
# block, trial =  1 62
# nan
# block, trial =  1 63
# 1162.0
# block, trial =  1 64
# nan
# block, trial =  1 65
# 1020.0
# block, trial =  1 66
# 1237.0
# block, trial =  1 67
# 1057.0
# block, trial =  1 68
# 1206.0
# block, trial =  1 69
# 1039.0
# block, trial =  1 70
# 1137.0
# block, trial =  1 71
# 1231.0
# block, trial =  1 72
# nan
# block, trial =  1 73
# 1278.0
# block, trial =  1 74
# nan
# block, trial =  1 75
# 1225.0
# block, trial =  1 76
# nan
# block, trial =  1 77
# 1013.0
# block, trial =  1 78
# nan
# block, trial =  1 79
# 1142.0
# block, trial =  1 80
# 1426.0
# block, trial =  1 81
# nan
# block, trial =  1 82
# 1309.0
# block, trial =  1 83
# 1288.0
# block, trial =  1 84
# 1254.0
# block, trial =  1 85
# 1341.0
# block, trial =  1 86
# 1074.0
# block, trial =  1 87
# 1109.0
# block, trial =  1 88
# 1336.0
# block, trial =  1 89
# nan
# block, trial =  1 90
# nan
# block, trial =  1 91
# 1416.0
# block, trial =  1 92
# 1217.0
# block, trial =  1 93
# 1340.0
# block, trial =  1 94
# nan
# block, trial =  1 95
# nan
# block, trial =  1 96
# 1083.0
# block, trial =  1 97
# 1333.0
# block, trial =  1 98
# 1188.0
# block, trial =  1 99
# nan
# block, trial =  1 100
# 1059.0
# block, trial =  1 101
# 993.0
# block, trial =  1 102
# 1024.0
# block, trial =  1 103
# nan
# block, trial =  1 104
# 1190.0
# block, trial =  1 105
# 1114.0
# block, trial =  1 106
# 1067.0
# block, trial =  1 107
# 1284.0
# block, trial =  1 108
# 1261.0
# block, trial =  1 109
# 1248.0
# block, trial =  1 110
# 1247.0
# block, trial =  1 111
# 1140.0
# block, trial =  1 112
# 1061.0
# block, trial =  1 113
# nan
# block, trial =  1 114
# nan
# block, trial =  1 115
# nan
# block, trial =  1 116
# 913.0
# block, trial =  1 117
# 962.0
# block, trial =  1 118
# nan
# block, trial =  1 119
# nan
# block, trial =  1 120
# nan
# block, trial =  1 121
# 1193.0
# block, trial =  1 122
# 1123.0
# block, trial =  1 123
# nan
# block, trial =  1 124
# nan
# block, trial =  1 125
# nan
# block, trial =  1 126
# nan
# block, trial =  1 127
# nan
# block, trial =  1 128
# 1325.0
# block, trial =  1 129
# 1295.0
# block, trial =  1 130
# 1140.0
# block, trial =  1 131
# nan
# block, trial =  1 132
# nan
# block, trial =  1 133
# 1227.0
# block, trial =  1 134
# nan
# block, trial =  1 135
# nan
# block, trial =  1 136
# nan
# block, trial =  1 137
# nan
# block, trial =  1 138
# nan
# block, trial =  1 139
# nan
# block, trial =  1 140
# 1198.0
# block, trial =  1 141
# 1105.0
# block, trial =  1 142
# 1036.0
# block, trial =  1 143
# 1262.0
# block, trial =  1 144
# nan
# block, trial =  1 145
# nan
# block, trial =  1 146
# nan
# block, trial =  1 147
# 601.0
# block, trial =  1 148
# nan
# block, trial =  1 149
# 1016.0
# block, trial =  1 150
# 1354.0
# block, trial =  1 151
# 1119.0
# block, trial =  1 152
# 1136.0
# block, trial =  1 153
# nan
# block, trial =  1 154
# 1219.0
# block, trial =  1 155
# 1277.0
# block, trial =  1 156
# 1261.0
# block, trial =  1 157
# 1324.0
# block, trial =  1 158
# nan
# block, trial =  1 159
# nan
# block, trial =  1 160
# 1191.0
# block, trial =  1 161
# 1463.0
# block, trial =  1 162
# nan
# block, trial =  1 163
# nan
# block, trial =  1 164
# 1113.0
# block, trial =  1 165
# nan
# block, trial =  1 166
# 1336.0
# block, trial =  1 167
# nan
# block, trial =  1 168
# 1203.0
# block, trial =  1 169
# 1325.0
# block, trial =  1 170
# 1425.0
# block, trial =  1 171
# 1070.0
# block, trial =  1 172
# 1344.0
# block, trial =  1 173
# nan
# block, trial =  1 174
# 1244.0
# block, trial =  1 175
# 1086.0
# block, trial =  1 176
# nan
# block, trial =  1 177
# 1084.0
# block, trial =  1 178
# nan
# block, trial =  1 179
# nan
# block, trial =  1 180
# nan
# block, trial =  1 181
# 1388.0
# block, trial =  1 182
# nan
# block, trial =  1 183
# 972.0
# block, trial =  1 184
# nan
# block, trial =  1 185
# nan
# block, trial =  1 186
# nan
# block, trial =  1 187
# nan
# block, trial =  1 188
# nan
# block, trial =  1 189
# 1237.0
# block, trial =  1 190
# nan
# block, trial =  1 191
# 1265.0
# block, trial =  1 192
# nan
# block, trial =  1 193
# 486.0
# block, trial =  1 194
# 1006.0
# block, trial =  1 195
# nan
# block, trial =  1 196
# 1249.0
# block, trial =  1 197
# 1326.0
# block, trial =  1 198
# 1182.0
# block, trial =  1 199
# 1342.0
# block, trial =  2 0
# nan
# block, trial =  2 1
# 1323.0
# block, trial =  2 2
# 1063.0
# block, trial =  2 3
# 995.0
# block, trial =  2 4
# nan
# block, trial =  2 5
# nan
# block, trial =  2 6
# 1152.0
# block, trial =  2 7
# nan
# block, trial =  2 8
# nan
# block, trial =  2 9
# nan
# block, trial =  2 10
# 1259.0
# block, trial =  2 11
# nan
# block, trial =  2 12
# nan
# block, trial =  2 13
# 1323.0
# block, trial =  2 14
# nan
# block, trial =  2 15
# nan
# block, trial =  2 16
# nan
# block, trial =  2 17
# 1345.0
# block, trial =  2 18
# 1106.0
# block, trial =  2 19
# nan
# block, trial =  2 20
# 1056.0
# block, trial =  2 21
# 1415.0
# block, trial =  2 22
# 1269.0
# block, trial =  2 23
# nan
# block, trial =  2 24
# 1104.0
# block, trial =  2 25
# nan
# block, trial =  2 26
# nan
# block, trial =  2 27
# 1649.0
# block, trial =  2 28
# nan
# block, trial =  2 29
# nan
# block, trial =  2 30
# nan
# block, trial =  2 31
# nan
# block, trial =  2 32
# 1096.0
# block, trial =  2 33
# 1362.0
# block, trial =  2 34
# 1346.0
# block, trial =  2 35
# nan
# block, trial =  2 36
# 991.0
# block, trial =  2 37
# nan
# block, trial =  2 38
# nan
# block, trial =  2 39
# nan
# block, trial =  2 40
# 1023.0
# block, trial =  2 41
# 1369.0
# block, trial =  2 42
# 1170.0
# block, trial =  2 43
# nan
# block, trial =  2 44
# nan
# block, trial =  2 45
# 1042.0
# block, trial =  2 46
# nan
# block, trial =  2 47
# nan
# block, trial =  2 48
# nan
# block, trial =  2 49
# nan
# block, trial =  2 50
# nan
# block, trial =  2 51
# 1207.0
# block, trial =  2 52
# nan
# block, trial =  2 53
# 1084.0
# block, trial =  2 54
# 1123.0
# block, trial =  2 55
# 380.0
# block, trial =  2 56
# nan
# block, trial =  2 57
# nan
# block, trial =  2 58
# nan
# block, trial =  2 59
# nan
# block, trial =  2 60
# 1007.0
# block, trial =  2 61
# 415.0
# block, trial =  2 62
# 1152.0
# block, trial =  2 63
# nan
# block, trial =  2 64
# 1134.0
# block, trial =  2 65
# 1201.0
# block, trial =  2 66
# 1231.0
# block, trial =  2 67
# 1362.0
# block, trial =  2 68
# 1072.0
# block, trial =  2 69
# 697.0
# block, trial =  2 70
# 1237.0
# block, trial =  2 71
# 1204.0
# block, trial =  2 72
# 1143.0
# block, trial =  2 73
# nan
# block, trial =  2 74
# 1095.0
# block, trial =  2 75
# nan
# block, trial =  2 76
# 926.0
# block, trial =  2 77
# 1082.0
# block, trial =  2 78
# nan
# block, trial =  2 79
# 1129.0
# block, trial =  2 80
# 1150.0
# block, trial =  2 81
# nan
# block, trial =  2 82
# 1410.0
# block, trial =  2 83
# 1030.0
# block, trial =  2 84
# 984.0
# block, trial =  2 85
# 928.0
# block, trial =  2 86
# 1220.0
# block, trial =  2 87
# 1092.0
# block, trial =  2 88
# 1299.0
# block, trial =  2 89
# nan
# block, trial =  2 90
# nan
# block, trial =  2 91
# 975.0
# block, trial =  2 92
# 1329.0
# block, trial =  2 93
# 991.0
# block, trial =  2 94
# 1227.0
# block, trial =  2 95
# nan
# block, trial =  2 96
# nan
# block, trial =  2 97
# nan
# block, trial =  2 98
# 1038.0
# block, trial =  2 99
# 1052.0
# block, trial =  2 100
# nan
# block, trial =  2 101
# 1211.0
# block, trial =  2 102
# 1131.0
# block, trial =  2 103
# 972.0
# block, trial =  2 104
# 1125.0
# block, trial =  2 105
# nan
# block, trial =  2 106
# 1002.0
# block, trial =  2 107
# 1064.0
# block, trial =  2 108
# 1179.0
# block, trial =  2 109
# 1280.0
# block, trial =  2 110
# 414.0
# block, trial =  2 111
# nan
# block, trial =  2 112
# nan
# block, trial =  2 113
# 1183.0
# block, trial =  2 114
# 1143.0
# block, trial =  2 115
# 1029.0
# block, trial =  2 116
# 1235.0
# block, trial =  2 117
# nan
# block, trial =  2 118
# 1137.0
# block, trial =  2 119
# 1194.0
# block, trial =  2 120
# 1263.0
# block, trial =  2 121
# 1109.0
# block, trial =  2 122
# 1242.0
# block, trial =  2 123
# nan
# block, trial =  2 124
# nan
# block, trial =  2 125
# nan
# block, trial =  2 126
# 1355.0
# block, trial =  2 127
# nan
# block, trial =  2 128
# 1163.0
# block, trial =  2 129
# 1174.0
# block, trial =  2 130
# 1173.0
# block, trial =  2 131
# 1160.0
# block, trial =  2 132
# 639.0
# block, trial =  2 133
# 1061.0
# block, trial =  2 134
# 1009.0
# block, trial =  2 135
# 966.0
# block, trial =  2 136
# 1309.0
# block, trial =  2 137
# 1121.0
# block, trial =  2 138
# 1109.0
# block, trial =  2 139
# 1219.0
# block, trial =  2 140
# nan
# block, trial =  2 141
# 1217.0
# block, trial =  2 142
# nan
# block, trial =  2 143
# nan
# block, trial =  2 144
# nan
# block, trial =  2 145
# 1305.0
# block, trial =  2 146
# 936.0
# block, trial =  2 147
# nan
# block, trial =  2 148
# 1356.0
# block, trial =  2 149
# nan
# block, trial =  2 150
# nan
# block, trial =  2 151
# 1038.0
# block, trial =  2 152
# 1052.0
# block, trial =  2 153
# nan
# block, trial =  2 154
# 1037.0
# block, trial =  2 155
# nan
# block, trial =  2 156
# nan
# block, trial =  2 157
# nan
# block, trial =  2 158
# 1046.0
# block, trial =  2 159
# 942.0
# block, trial =  2 160
# 1290.0
# block, trial =  2 161
# 494.0
# block, trial =  2 162
# 1017.0
# block, trial =  2 163
# 968.0
# block, trial =  2 164
# 610.0
# block, trial =  2 165
# nan
# block, trial =  2 166
# nan
# block, trial =  2 167
# nan
# block, trial =  2 168
# 1092.0
# block, trial =  2 169
# 1191.0
# block, trial =  2 170
# nan
# block, trial =  2 171
# 1302.0
# block, trial =  2 172
# 1072.0
# block, trial =  2 173
# 1043.0
# block, trial =  2 174
# nan
# block, trial =  2 175
# 1124.0
# block, trial =  2 176
# nan
# block, trial =  2 177
# 1117.0
# block, trial =  2 178
# nan
# block, trial =  2 179
# 1298.0
# block, trial =  2 180
# nan
# block, trial =  2 181
# 1170.0
# block, trial =  2 182
# 1191.0
# block, trial =  2 183
# nan
# block, trial =  2 184
# nan
# block, trial =  2 185
# 1070.0
# block, trial =  2 186
# 1007.0
# block, trial =  2 187
# 1218.0
# block, trial =  2 188
# nan
# block, trial =  2 189
# nan
# block, trial =  2 190
# nan
# block, trial =  2 191
# nan
# block, trial =  2 192
# nan
# block, trial =  2 193
# nan
# block, trial =  2 194
# nan
# block, trial =  2 195
# 1274.0
# block, trial =  2 196
# nan
# block, trial =  2 197
# nan
# block, trial =  2 198
# nan
# block, trial =  2 199
# nan
# FIN !!!
# Analysing subject BMC
# block, trial =  0 0
# nan
# block, trial =  0 1
# nan
# block, trial =  0 2
# 1129.0
# block, trial =  0 3
# nan
# block, trial =  0 4
# nan
# block, trial =  0 5
# nan
# block, trial =  0 6
# nan
# block, trial =  0 7
# 1085.0
# block, trial =  0 8
# 867.0
# block, trial =  0 9
# nan
# block, trial =  0 10
# 611.0
# block, trial =  0 11
# nan
# block, trial =  0 12
# 1090.0
# block, trial =  0 13
# nan
# block, trial =  0 14
# 689.0
# block, trial =  0 15
# nan
# block, trial =  0 16
# nan
# block, trial =  0 17
# nan
# block, trial =  0 18
# nan
# block, trial =  0 19
# nan
# block, trial =  0 20
# nan
# block, trial =  0 21
# nan
# block, trial =  0 22
# nan
# block, trial =  0 23
# 1230.0
# block, trial =  0 24
# nan
# block, trial =  0 25
# nan
# block, trial =  0 26
# nan
# block, trial =  0 27
# nan
# block, trial =  0 28
# 1002.0
# block, trial =  0 29
# nan
# block, trial =  0 30
# nan
# block, trial =  0 31
# nan
# block, trial =  0 32
# 1284.0
# block, trial =  0 33
# nan
# block, trial =  0 34
# nan
# block, trial =  0 35
# nan
# block, trial =  0 36
# nan
# block, trial =  0 37
# nan
# block, trial =  0 38
# nan
# block, trial =  0 39
# nan
# block, trial =  0 40
# nan
# block, trial =  0 41
# nan
# block, trial =  0 42
# nan
# block, trial =  0 43
# 1092.0
# block, trial =  0 44
# 712.0
# block, trial =  0 45
# nan
# block, trial =  0 46
# 1051.0
# block, trial =  0 47
# 1086.0
# block, trial =  0 48
# 671.0
# block, trial =  0 49
# nan
# block, trial =  0 50
# 1021.0
# block, trial =  0 51
# nan
# block, trial =  0 52
# nan
# block, trial =  0 53
# nan
# block, trial =  0 54
# 1132.0
# block, trial =  0 55
# 1394.0
# block, trial =  0 56
# 1085.0
# block, trial =  0 57
# nan
# block, trial =  0 58
# nan
# block, trial =  0 59
# nan
# block, trial =  0 60
# nan
# block, trial =  0 61
# nan
# block, trial =  0 62
# nan
# block, trial =  0 63
# nan
# block, trial =  0 64
# nan
# block, trial =  0 65
# nan
# block, trial =  0 66
# nan
# block, trial =  0 67
# 1173.0
# block, trial =  0 68
# nan
# block, trial =  0 69
# nan
# block, trial =  0 70
# nan
# block, trial =  0 71
# 1116.0
# block, trial =  0 72
# nan
# block, trial =  0 73
# nan
# block, trial =  0 74
# nan
# block, trial =  0 75
# nan
# block, trial =  0 76
# nan
# block, trial =  0 77
# nan
# block, trial =  0 78
# 600.0
# block, trial =  0 79
# nan
# block, trial =  0 80
# nan
# block, trial =  0 81
# 677.0
# block, trial =  0 82
# nan
# block, trial =  0 83
# nan
# block, trial =  0 84
# nan
# block, trial =  0 85
# 1376.0
# block, trial =  0 86
# nan
# block, trial =  0 87
# nan
# block, trial =  0 88
# nan
# block, trial =  0 89
# 999.0
# block, trial =  0 90
# nan
# block, trial =  0 91
# nan
# block, trial =  0 92
# nan
# block, trial =  0 93
# nan
# block, trial =  0 94
# nan
# block, trial =  0 95
# nan
# block, trial =  0 96
# nan
# block, trial =  0 97
# 1212.0
# block, trial =  0 98
# 800.0
# block, trial =  0 99
# nan
# block, trial =  0 100
# 759.0
# block, trial =  0 101
# nan
# block, trial =  0 102
# 1339.0
# block, trial =  0 103
# 1116.0
# block, trial =  0 104
# nan
# block, trial =  0 105
# nan
# block, trial =  0 106
# nan
# block, trial =  0 107
# nan
# block, trial =  0 108
# nan
# block, trial =  0 109
# 1000.0
# block, trial =  0 110
# nan
# block, trial =  0 111
# nan
# block, trial =  0 112
# nan
# block, trial =  0 113
# nan
# block, trial =  0 114
# nan
# block, trial =  0 115
# 979.0
# block, trial =  0 116
# nan
# block, trial =  0 117
# nan
# block, trial =  0 118
# nan
# block, trial =  0 119
# nan
# block, trial =  0 120
# nan
# block, trial =  0 121
# nan
# block, trial =  0 122
# 1274.0
# block, trial =  0 123
# nan
# block, trial =  0 124
# nan
# block, trial =  0 125
# 1301.0
# block, trial =  0 126
# nan
# block, trial =  0 127
# nan
# block, trial =  0 128
# 580.0
# block, trial =  0 129
# nan
# block, trial =  0 130
# 1211.0
# block, trial =  0 131
# nan
# block, trial =  0 132
# 1096.0
# block, trial =  0 133
# nan
# block, trial =  0 134
# nan
# block, trial =  0 135
# nan
# block, trial =  0 136
# 672.0
# block, trial =  0 137
# nan
# block, trial =  0 138
# nan
# block, trial =  0 139
# nan
# block, trial =  0 140
# nan
# block, trial =  0 141
# nan
# block, trial =  0 142
# 1193.0
# block, trial =  0 143
# nan
# block, trial =  0 144
# nan
# block, trial =  0 145
# 669.0
# block, trial =  0 146
# nan
# block, trial =  0 147
# nan
# block, trial =  0 148
# 1063.0
# block, trial =  0 149
# nan
# block, trial =  0 150
# nan
# block, trial =  0 151
# nan
# block, trial =  0 152
# nan
# block, trial =  0 153
# nan
# block, trial =  0 154
# nan
# block, trial =  0 155
# 963.0
# block, trial =  0 156
# nan
# block, trial =  0 157
# nan
# block, trial =  0 158
# nan
# block, trial =  0 159
# nan
# block, trial =  0 160
# nan
# block, trial =  0 161
# nan
# block, trial =  0 162
# nan
# block, trial =  0 163
# nan
# block, trial =  0 164
# nan
# block, trial =  0 165
# nan
# block, trial =  0 166
# nan
# block, trial =  0 167
# nan
# block, trial =  0 168
# nan
# block, trial =  0 169
# nan
# block, trial =  0 170
# nan
# block, trial =  0 171
# 955.0
# block, trial =  0 172
# 1165.0
# block, trial =  0 173
# nan
# block, trial =  0 174
# nan
# block, trial =  0 175
# nan
# block, trial =  0 176
# nan
# block, trial =  0 177
# 1411.0
# block, trial =  0 178
# nan
# block, trial =  0 179
# nan
# block, trial =  0 180
# nan
# block, trial =  0 181
# nan
# block, trial =  0 182
# nan
# block, trial =  0 183
# nan
# block, trial =  0 184
# nan
# block, trial =  0 185
# 1114.0
# block, trial =  0 186
# nan
# block, trial =  0 187
# nan
# block, trial =  0 188
# nan
# block, trial =  0 189
# 617.0
# block, trial =  0 190
# nan
# block, trial =  0 191
# nan
# block, trial =  0 192
# nan
# block, trial =  0 193
# nan
# block, trial =  0 194
# nan
# block, trial =  0 195
# nan
# block, trial =  0 196
# nan
# block, trial =  0 197
# nan
# block, trial =  0 198
# nan
# block, trial =  0 199
# nan
# block, trial =  1 0
# nan
# block, trial =  1 1
# 723.0
# block, trial =  1 2
# nan
# block, trial =  1 3
# nan
# block, trial =  1 4
# 1392.0
# block, trial =  1 5
# nan
# block, trial =  1 6
# nan
# block, trial =  1 7
# nan
# block, trial =  1 8
# nan
# block, trial =  1 9
# nan
# block, trial =  1 10
# 1292.0
# block, trial =  1 11
# 784.0
# block, trial =  1 12
# 373.0
# block, trial =  1 13
# nan
# block, trial =  1 14
# nan
# block, trial =  1 15
# 393.0
# block, trial =  1 16
# 1161.0
# block, trial =  1 17
# nan
# block, trial =  1 18
# 649.0
# block, trial =  1 19
# nan
# block, trial =  1 20
# nan
# block, trial =  1 21
# nan
# block, trial =  1 22
# nan
# block, trial =  1 23
# 1240.0
# block, trial =  1 24
# nan
# block, trial =  1 25
# nan
# block, trial =  1 26
# 860.0
# block, trial =  1 27
# nan
# block, trial =  1 28
# nan
# block, trial =  1 29
# 827.0
# block, trial =  1 30
# nan
# block, trial =  1 31
# nan
# block, trial =  1 32
# nan
# block, trial =  1 33
# nan
# block, trial =  1 34
# 1030.0
# block, trial =  1 35
# nan
# block, trial =  1 36
# nan
# block, trial =  1 37
# 1126.0
# block, trial =  1 38
# 1063.0
# block, trial =  1 39
# nan
# block, trial =  1 40
# 1332.0
# block, trial =  1 41
# nan
# block, trial =  1 42
# nan
# block, trial =  1 43
# nan
# block, trial =  1 44
# 1339.0
# block, trial =  1 45
# nan
# block, trial =  1 46
# 576.0
# block, trial =  1 47
# nan
# block, trial =  1 48
# 621.0
# block, trial =  1 49
# nan
# block, trial =  1 50
# 879.0
# block, trial =  1 51
# nan
# block, trial =  1 52
# nan
# block, trial =  1 53
# nan
# block, trial =  1 54
# 1077.0
# block, trial =  1 55
# nan
# block, trial =  1 56
# nan
# block, trial =  1 57
# nan
# block, trial =  1 58
# 1095.0
# block, trial =  1 59
# 971.0
# block, trial =  1 60
# nan
# block, trial =  1 61
# 1197.0
# block, trial =  1 62
# nan
# block, trial =  1 63
# nan
# block, trial =  1 64
# nan
# block, trial =  1 65
# nan
# block, trial =  1 66
# nan
# block, trial =  1 67
# 1020.0
# block, trial =  1 68
# 1193.0
# block, trial =  1 69
# 1064.0
# block, trial =  1 70
# 1036.0
# block, trial =  1 71
# nan
# block, trial =  1 72
# 1338.0
# block, trial =  1 73
# nan
# block, trial =  1 74
# nan
# block, trial =  1 75
# nan
# block, trial =  1 76
# 1261.0
# block, trial =  1 77
# nan
# block, trial =  1 78
# 1428.0
# block, trial =  1 79
# nan
# block, trial =  1 80
# nan
# block, trial =  1 81
# nan
# block, trial =  1 82
# 459.0
# block, trial =  1 83
# 673.0
# block, trial =  1 84
# nan
# block, trial =  1 85
# nan
# block, trial =  1 86
# nan
# block, trial =  1 87
# nan
# block, trial =  1 88
# 1239.0
# block, trial =  1 89
# 704.0
# block, trial =  1 90
# nan
# block, trial =  1 91
# 386.0
# block, trial =  1 92
# nan
# block, trial =  1 93
# nan
# block, trial =  1 94
# 1067.0
# block, trial =  1 95
# nan
# block, trial =  1 96
# 781.0
# block, trial =  1 97
# 1436.0
# block, trial =  1 98
# nan
# block, trial =  1 99
# nan
# block, trial =  1 100
# nan
# block, trial =  1 101
# 544.0
# block, trial =  1 102
# 949.0
# block, trial =  1 103
# 626.0
# block, trial =  1 104
# nan
# block, trial =  1 105
# 1062.0
# block, trial =  1 106
# 1042.0
# block, trial =  1 107
# nan
# block, trial =  1 108
# nan
# block, trial =  1 109
# nan
# block, trial =  1 110
# nan
# block, trial =  1 111
# nan
# block, trial =  1 112
# nan
# block, trial =  1 113
# nan
# block, trial =  1 114
# 1115.0
# block, trial =  1 115
# nan
# block, trial =  1 116
# nan
# block, trial =  1 117
# nan
# block, trial =  1 118
# 695.0
# block, trial =  1 119
# nan
# block, trial =  1 120
# nan
# block, trial =  1 121
# nan
# block, trial =  1 122
# 1072.0
# block, trial =  1 123
# 1048.0
# block, trial =  1 124
# 1165.0
# block, trial =  1 125
# nan
# block, trial =  1 126
# nan
# block, trial =  1 127
# 1449.0
# block, trial =  1 128
# nan
# block, trial =  1 129
# nan
# block, trial =  1 130
# nan
# block, trial =  1 131
# nan
# block, trial =  1 132
# nan
# block, trial =  1 133
# nan
# block, trial =  1 134
# nan
# block, trial =  1 135
# nan
# block, trial =  1 136
# 1397.0
# block, trial =  1 137
# nan
# block, trial =  1 138
# 1272.0
# block, trial =  1 139
# nan
# block, trial =  1 140
# nan
# block, trial =  1 141
# 808.0
# block, trial =  1 142
# nan
# block, trial =  1 143
# nan
# block, trial =  1 144
# nan
# block, trial =  1 145
# nan
# block, trial =  1 146
# nan
# block, trial =  1 147
# nan
# block, trial =  1 148
# nan
# block, trial =  1 149
# 598.0
# block, trial =  1 150
# nan
# block, trial =  1 151
# nan
# block, trial =  1 152
# 585.0
# block, trial =  1 153
# 1385.0
# block, trial =  1 154
# 644.0
# block, trial =  1 155
# nan
# block, trial =  1 156
# 635.0
# block, trial =  1 157
# 638.0
# block, trial =  1 158
# 690.0
# block, trial =  1 159
# nan
# block, trial =  1 160
# nan
# block, trial =  1 161
# 1245.0
# block, trial =  1 162
# nan
# block, trial =  1 163
# 1234.0
# block, trial =  1 164
# nan
# block, trial =  1 165
# 1240.0
# block, trial =  1 166
# nan
# block, trial =  1 167
# 1289.0
# block, trial =  1 168
# nan
# block, trial =  1 169
# nan
# block, trial =  1 170
# nan
# block, trial =  1 171
# nan
# block, trial =  1 172
# 779.0
# block, trial =  1 173
# nan
# block, trial =  1 174
# 1197.0
# block, trial =  1 175
# 1409.0
# block, trial =  1 176
# 770.0
# block, trial =  1 177
# nan
# block, trial =  1 178
# 1114.0
# block, trial =  1 179
# nan
# block, trial =  1 180
# nan
# block, trial =  1 181
# 410.0
# block, trial =  1 182
# 715.0
# block, trial =  1 183
# nan
# block, trial =  1 184
# nan
# block, trial =  1 185
# nan
# block, trial =  1 186
# 1208.0
# block, trial =  1 187
# 1075.0
# block, trial =  1 188
# nan
# block, trial =  1 189
# nan
# block, trial =  1 190
# nan
# block, trial =  1 191
# 413.0
# block, trial =  1 192
# nan
# block, trial =  1 193
# 948.0
# block, trial =  1 194
# nan
# block, trial =  1 195
# 1419.0
# block, trial =  1 196
# nan
# block, trial =  1 197
# 979.0
# block, trial =  1 198
# 667.0
# block, trial =  1 199
# 1287.0
# block, trial =  2 0
# 702.0
# block, trial =  2 1
# 1409.0
# block, trial =  2 2
# 1078.0
# block, trial =  2 3
# nan
# block, trial =  2 4
# nan
# block, trial =  2 5
# nan
# block, trial =  2 6
# nan
# block, trial =  2 7
# nan
# block, trial =  2 8
# 1323.0
# block, trial =  2 9
# nan
# block, trial =  2 10
# nan
# block, trial =  2 11
# nan
# block, trial =  2 12
# nan
# block, trial =  2 13
# nan
# block, trial =  2 14
# nan
# block, trial =  2 15
# 1146.0
# block, trial =  2 16
# nan
# block, trial =  2 17
# nan
# block, trial =  2 18
# nan
# block, trial =  2 19
# nan
# block, trial =  2 20
# nan
# block, trial =  2 21
# 1517.0
# block, trial =  2 22
# 1296.0
# block, trial =  2 23
# nan
# block, trial =  2 24
# 1013.0
# block, trial =  2 25
# 1175.0
# block, trial =  2 26
# nan
# block, trial =  2 27
# 687.0
# block, trial =  2 28
# nan
# block, trial =  2 29
# 1241.0
# block, trial =  2 30
# 1345.0
# block, trial =  2 31
# nan
# block, trial =  2 32
# nan
# block, trial =  2 33
# 742.0
# block, trial =  2 34
# nan
# block, trial =  2 35
# nan
# block, trial =  2 36
# nan
# block, trial =  2 37
# nan
# block, trial =  2 38
# 386.0
# block, trial =  2 39
# 696.0
# block, trial =  2 40
# nan
# block, trial =  2 41
# nan
# block, trial =  2 42
# 974.0
# block, trial =  2 43
# 635.0
# block, trial =  2 44
# nan
# block, trial =  2 45
# nan
# block, trial =  2 46
# 874.0
# block, trial =  2 47
# 760.0
# block, trial =  2 48
# nan
# block, trial =  2 49
# nan
# block, trial =  2 50
# 659.0
# block, trial =  2 51
# nan
# block, trial =  2 52
# nan
# block, trial =  2 53
# nan
# block, trial =  2 54
# 1133.0
# block, trial =  2 55
# nan
# block, trial =  2 56
# 1438.0
# block, trial =  2 57
# nan
# block, trial =  2 58
# nan
# block, trial =  2 59
# 1496.0
# block, trial =  2 60
# nan
# block, trial =  2 61
# 1016.0
# block, trial =  2 62
# 1134.0
# block, trial =  2 63
# nan
# block, trial =  2 64
# 1196.0
# block, trial =  2 65
# nan
# block, trial =  2 66
# 512.0
# block, trial =  2 67
# 1598.0
# block, trial =  2 68
# nan
# block, trial =  2 69
# nan
# block, trial =  2 70
# 1233.0
# block, trial =  2 71
# 669.0
# block, trial =  2 72
# nan
# block, trial =  2 73
# 554.0
# block, trial =  2 74
# 965.0
# block, trial =  2 75
# 667.0
# block, trial =  2 76
# nan
# block, trial =  2 77
# 953.0
# block, trial =  2 78
# 528.0
# block, trial =  2 79
# 404.0
# block, trial =  2 80
# 490.0
# block, trial =  2 81
# nan
# block, trial =  2 82
# nan
# block, trial =  2 83
# 1067.0
# block, trial =  2 84
# 982.0
# block, trial =  2 85
# 1023.0
# block, trial =  2 86
# 697.0
# block, trial =  2 87
# nan
# block, trial =  2 88
# nan
# block, trial =  2 89
# 1128.0
# block, trial =  2 90
# 569.0
# block, trial =  2 91
# nan
# block, trial =  2 92
# 768.0
# block, trial =  2 93
# nan
# block, trial =  2 94
# nan
# block, trial =  2 95
# nan
# block, trial =  2 96
# 1206.0
# block, trial =  2 97
# 571.0
# block, trial =  2 98
# nan
# block, trial =  2 99
# nan
# block, trial =  2 100
# nan
# block, trial =  2 101
# nan
# block, trial =  2 102
# nan
# block, trial =  2 103
# nan
# block, trial =  2 104
# nan
# block, trial =  2 105
# nan
# block, trial =  2 106
# nan
# block, trial =  2 107
# 866.0
# block, trial =  2 108
# 777.0
# block, trial =  2 109
# 1345.0
# block, trial =  2 110
# nan
# block, trial =  2 111
# nan
# block, trial =  2 112
# nan
# block, trial =  2 113
# nan
# block, trial =  2 114
# nan
# block, trial =  2 115
# nan
# block, trial =  2 116
# nan
# block, trial =  2 117
# 501.0
# block, trial =  2 118
# 489.0
# block, trial =  2 119
# nan
# block, trial =  2 120
# 1356.0
# block, trial =  2 121
# nan
# block, trial =  2 122
# nan
# block, trial =  2 123
# 668.0
# block, trial =  2 124
# 907.0
# block, trial =  2 125
# 523.0
# block, trial =  2 126
# nan
# block, trial =  2 127
# 824.0
# block, trial =  2 128
# 916.0
# block, trial =  2 129
# nan
# block, trial =  2 130
# nan
# block, trial =  2 131
# nan
# block, trial =  2 132
# nan
# block, trial =  2 133
# nan
# block, trial =  2 134
# 642.0
# block, trial =  2 135
# nan
# block, trial =  2 136
# nan
# block, trial =  2 137
# nan
# block, trial =  2 138
# 1277.0
# block, trial =  2 139
# nan
# block, trial =  2 140
# nan
# block, trial =  2 141
# 795.0
# block, trial =  2 142
# nan
# block, trial =  2 143
# nan
# block, trial =  2 144
# nan
# block, trial =  2 145
# 827.0
# block, trial =  2 146
# nan
# block, trial =  2 147
# 1490.0
# block, trial =  2 148
# 1487.0
# block, trial =  2 149
# 1061.0
# block, trial =  2 150
# 1285.0
# block, trial =  2 151
# nan
# block, trial =  2 152
# 604.0
# block, trial =  2 153
# nan
# block, trial =  2 154
# nan
# block, trial =  2 155
# nan
# block, trial =  2 156
# 1261.0
# block, trial =  2 157
# 1305.0
# block, trial =  2 158
# nan
# block, trial =  2 159
# nan
# block, trial =  2 160
# 730.0
# block, trial =  2 161
# 578.0
# block, trial =  2 162
# 638.0
# block, trial =  2 163
# nan
# block, trial =  2 164
# nan
# block, trial =  2 165
# 1237.0
# block, trial =  2 166
# 1186.0
# block, trial =  2 167
# nan
# block, trial =  2 168
# 633.0
# block, trial =  2 169
# nan
# block, trial =  2 170
# nan
# block, trial =  2 171
# 1549.0
# block, trial =  2 172
# nan
# block, trial =  2 173
# 637.0
# block, trial =  2 174
# nan
# block, trial =  2 175
# 655.0
# block, trial =  2 176
# 630.0
# block, trial =  2 177
# nan
# block, trial =  2 178
# nan
# block, trial =  2 179
# nan
# block, trial =  2 180
# nan
# block, trial =  2 181
# nan
# block, trial =  2 182
# nan
# block, trial =  2 183
# nan
# block, trial =  2 184
# 664.0
# block, trial =  2 185
# nan
# block, trial =  2 186
# nan
# block, trial =  2 187
# 486.0
# block, trial =  2 188
# nan
# block, trial =  2 189
# nan
# block, trial =  2 190
# nan
# block, trial =  2 191
# nan
# block, trial =  2 192
# 1192.0
# block, trial =  2 193
# nan
# block, trial =  2 194
# nan
# block, trial =  2 195
# 775.0
# block, trial =  2 196
# 1023.0
# block, trial =  2 197
# 1153.0
# block, trial =  2 198
# nan
# block, trial =  2 199
# 439.0
# FIN !!!
# Analysing subject CS
# block, trial =  0 0
# nan
# block, trial =  0 1
# nan
# block, trial =  0 2
# nan
# block, trial =  0 3
# 1452.0
# block, trial =  0 4
# nan
# block, trial =  0 5
# 917.0
# block, trial =  0 6
# 1193.0
# block, trial =  0 7
# 1092.0
# block, trial =  0 8
# 637.0
# block, trial =  0 9
# 1581.0
# block, trial =  0 10
# 1053.0
# block, trial =  0 11
# 978.0
# block, trial =  0 12
# 1070.0
# block, trial =  0 13
# 605.0
# block, trial =  0 14
# 968.0
# block, trial =  0 15
# nan
# block, trial =  0 16
# nan
# block, trial =  0 17
# nan
# block, trial =  0 18
# 1261.0
# block, trial =  0 19
# 699.0
# block, trial =  0 20
# nan
# block, trial =  0 21
# 730.0
# block, trial =  0 22
# 1341.0
# block, trial =  0 23
# 1158.0
# block, trial =  0 24
# 766.0
# block, trial =  0 25
# 792.0
# block, trial =  0 26
# nan
# block, trial =  0 27
# 924.0
# block, trial =  0 28
# nan
# block, trial =  0 29
# 1011.0
# block, trial =  0 30
# nan
# block, trial =  0 31
# 857.0
# block, trial =  0 32
# nan
# block, trial =  0 33
# 1033.0
# block, trial =  0 34
# 992.0
# block, trial =  0 35
# 1015.0
# block, trial =  0 36
# 1301.0
# block, trial =  0 37
# 627.0
# block, trial =  0 38
# nan
# block, trial =  0 39
# 1072.0
# block, trial =  0 40
# 1099.0
# block, trial =  0 41
# 999.0
# block, trial =  0 42
# nan
# block, trial =  0 43
# 717.0
# block, trial =  0 44
# 817.0
# block, trial =  0 45
# nan
# block, trial =  0 46
# nan
# block, trial =  0 47
# 859.0
# block, trial =  0 48
# 1085.0
# block, trial =  0 49
# 1211.0
# block, trial =  0 50
# 584.0
# block, trial =  0 51
# nan
# block, trial =  0 52
# 998.0
# block, trial =  0 53
# 1070.0
# block, trial =  0 54
# 767.0
# block, trial =  0 55
# 1046.0
# block, trial =  0 56
# 736.0
# block, trial =  0 57
# 927.0
# block, trial =  0 58
# 960.0
# block, trial =  0 59
# nan
# block, trial =  0 60
# 889.0
# block, trial =  0 61
# nan
# block, trial =  0 62
# 1102.0
# block, trial =  0 63
# nan
# block, trial =  0 64
# 368.0
# block, trial =  0 65
# 852.0
# block, trial =  0 66
# 844.0
# block, trial =  0 67
# nan
# block, trial =  0 68
# 838.0
# block, trial =  0 69
# nan
# block, trial =  0 70
# nan
# block, trial =  0 71
# 1247.0
# block, trial =  0 72
# 988.0
# block, trial =  0 73
# 1202.0
# block, trial =  0 74
# 752.0
# block, trial =  0 75
# 746.0
# block, trial =  0 76
# nan
# block, trial =  0 77
# nan
# block, trial =  0 78
# 1304.0
# block, trial =  0 79
# 852.0
# block, trial =  0 80
# 825.0
# block, trial =  0 81
# 879.0
# block, trial =  0 82
# 910.0
# block, trial =  0 83
# 969.0
# block, trial =  0 84
# 807.0
# block, trial =  0 85
# 1011.0
# block, trial =  0 86
# 857.0
# block, trial =  0 87
# 825.0
# block, trial =  0 88
# 716.0
# block, trial =  0 89
# nan
# block, trial =  0 90
# 401.0
# block, trial =  0 91
# 811.0
# block, trial =  0 92
# 1295.0
# block, trial =  0 93
# 977.0
# block, trial =  0 94
# 1014.0
# block, trial =  0 95
# nan
# block, trial =  0 96
# 400.0
# block, trial =  0 97
# 322.0
# block, trial =  0 98
# 972.0
# block, trial =  0 99
# nan
# block, trial =  0 100
# 949.0
# block, trial =  0 101
# 881.0
# block, trial =  0 102
# 795.0
# block, trial =  0 103
# nan
# block, trial =  0 104
# 769.0
# block, trial =  0 105
# 1141.0
# block, trial =  0 106
# 1345.0
# block, trial =  0 107
# 975.0
# block, trial =  0 108
# nan
# block, trial =  0 109
# nan
# block, trial =  0 110
# nan
# block, trial =  0 111
# 1392.0
# block, trial =  0 112
# nan
# block, trial =  0 113
# nan
# block, trial =  0 114
# 423.0
# block, trial =  0 115
# 150.0
# block, trial =  0 116
# 979.0
# block, trial =  0 117
# 1206.0
# block, trial =  0 118
# 1205.0
# block, trial =  0 119
# 724.0
# block, trial =  0 120
# nan
# block, trial =  0 121
# 1354.0
# block, trial =  0 122
# 760.0
# block, trial =  0 123
# 676.0
# block, trial =  0 124
# nan
# block, trial =  0 125
# 899.0
# block, trial =  0 126
# 689.0
# block, trial =  0 127
# 850.0
# block, trial =  0 128
# 381.0
# block, trial =  0 129
# 807.0
# block, trial =  0 130
# 828.0
# block, trial =  0 131
# 944.0
# block, trial =  0 132
# 754.0
# block, trial =  0 133
# nan
# block, trial =  0 134
# 971.0
# block, trial =  0 135
# 912.0
# block, trial =  0 136
# 785.0
# block, trial =  0 137
# 648.0
# block, trial =  0 138
# nan
# block, trial =  0 139
# 711.0
# block, trial =  0 140
# 730.0
# block, trial =  0 141
# 777.0
# block, trial =  0 142
# nan
# block, trial =  0 143
# nan
# block, trial =  0 144
# 1092.0
# block, trial =  0 145
# 718.0
# block, trial =  0 146
# 1056.0
# block, trial =  0 147
# 751.0
# block, trial =  0 148
# 704.0
# block, trial =  0 149
# 540.0
# block, trial =  0 150
# 612.0
# block, trial =  0 151
# nan
# block, trial =  0 152
# 820.0
# block, trial =  0 153
# 937.0
# block, trial =  0 154
# 701.0
# block, trial =  0 155
# nan
# block, trial =  0 156
# nan
# block, trial =  0 157
# 1046.0
# block, trial =  0 158
# nan
# block, trial =  0 159
# nan
# block, trial =  0 160
# nan
# block, trial =  0 161
# 992.0
# block, trial =  0 162
# 731.0
# block, trial =  0 163
# nan
# block, trial =  0 164
# 1010.0
# block, trial =  0 165
# 1178.0
# block, trial =  0 166
# nan
# block, trial =  0 167
# 983.0
# block, trial =  0 168
# 1375.0
# block, trial =  0 169
# 780.0
# block, trial =  0 170
# nan
# block, trial =  0 171
# 1299.0
# block, trial =  0 172
# 937.0
# block, trial =  0 173
# 970.0
# block, trial =  0 174
# nan
# block, trial =  0 175
# 1016.0
# block, trial =  0 176
# nan
# block, trial =  0 177
# nan
# block, trial =  0 178
# 1280.0
# block, trial =  0 179
# 1314.0
# block, trial =  0 180
# 1185.0
# block, trial =  0 181
# 944.0
# block, trial =  0 182
# 966.0
# block, trial =  0 183
# 1073.0
# block, trial =  0 184
# nan
# block, trial =  0 185
# 849.0
# block, trial =  0 186
# 858.0
# block, trial =  0 187
# 951.0
# block, trial =  0 188
# nan
# block, trial =  0 189
# 988.0
# block, trial =  0 190
# nan
# block, trial =  0 191
# 985.0
# block, trial =  0 192
# 622.0
# block, trial =  0 193
# 808.0
# block, trial =  0 194
# 748.0
# block, trial =  0 195
# 369.0
# block, trial =  0 196
# 940.0
# block, trial =  0 197
# 820.0
# block, trial =  0 198
# 383.0
# block, trial =  0 199
# nan
# block, trial =  1 0
# 803.0
# block, trial =  1 1
# 1288.0
# block, trial =  1 2
# 882.0
# block, trial =  1 3
# 909.0
# block, trial =  1 4
# 1040.0
# block, trial =  1 5
# 909.0
# block, trial =  1 6
# 834.0
# block, trial =  1 7
# 1143.0
# block, trial =  1 8
# 872.0
# block, trial =  1 9
# 950.0
# block, trial =  1 10
# 1558.0
# block, trial =  1 11
# 1307.0
# block, trial =  1 12
# nan
# block, trial =  1 13
# nan
# block, trial =  1 14
# 965.0
# block, trial =  1 15
# 800.0
# block, trial =  1 16
# 758.0
# block, trial =  1 17
# 786.0
# block, trial =  1 18
# 971.0
# block, trial =  1 19
# 955.0
# block, trial =  1 20
# 1016.0
# block, trial =  1 21
# 1098.0
# block, trial =  1 22
# 588.0
# block, trial =  1 23
# 760.0
# block, trial =  1 24
# 1234.0
# block, trial =  1 25
# 943.0
# block, trial =  1 26
# nan
# block, trial =  1 27
# 799.0
# block, trial =  1 28
# 1330.0
# block, trial =  1 29
# 985.0
# block, trial =  1 30
# 712.0
# block, trial =  1 31
# 660.0
# block, trial =  1 32
# nan
# block, trial =  1 33
# 808.0
# block, trial =  1 34
# nan
# block, trial =  1 35
# 885.0
# block, trial =  1 36
# nan
# block, trial =  1 37
# nan
# block, trial =  1 38
# 1040.0
# block, trial =  1 39
# 885.0
# block, trial =  1 40
# 843.0
# block, trial =  1 41
# 1252.0
# block, trial =  1 42
# 936.0
# block, trial =  1 43
# 721.0
# block, trial =  1 44
# 705.0
# block, trial =  1 45
# 695.0
# block, trial =  1 46
# 1013.0
# block, trial =  1 47
# 813.0
# block, trial =  1 48
# 364.0
# block, trial =  1 49
# 737.0
# block, trial =  1 50
# 549.0
# block, trial =  1 51
# 861.0
# block, trial =  1 52
# 976.0
# block, trial =  1 53
# nan
# block, trial =  1 54
# nan
# block, trial =  1 55
# nan
# block, trial =  1 56
# 620.0
# block, trial =  1 57
# 981.0
# block, trial =  1 58
# 755.0
# block, trial =  1 59
# 706.0
# block, trial =  1 60
# 855.0
# block, trial =  1 61
# 1017.0
# block, trial =  1 62
# nan
# block, trial =  1 63
# nan
# block, trial =  1 64
# nan
# block, trial =  1 65
# 705.0
# block, trial =  1 66
# 924.0
# block, trial =  1 67
# 735.0
# block, trial =  1 68
# 457.0
# block, trial =  1 69
# 743.0
# block, trial =  1 70
# 735.0
# block, trial =  1 71
# 991.0
# block, trial =  1 72
# 803.0
# block, trial =  1 73
# nan
# block, trial =  1 74
# 982.0
# block, trial =  1 75
# 902.0
# block, trial =  1 76
# 915.0
# block, trial =  1 77
# 744.0
# block, trial =  1 78
# 908.0
# block, trial =  1 79
# 769.0
# block, trial =  1 80
# 1050.0
# block, trial =  1 81
# nan
# block, trial =  1 82
# 786.0
# block, trial =  1 83
# 1050.0
# block, trial =  1 84
# 898.0
# block, trial =  1 85
# 755.0
# block, trial =  1 86
# 703.0
# block, trial =  1 87
# 699.0
# block, trial =  1 88
# 960.0
# block, trial =  1 89
# 779.0
# block, trial =  1 90
# 654.0
# block, trial =  1 91
# 691.0
# block, trial =  1 92
# 845.0
# block, trial =  1 93
# 844.0
# block, trial =  1 94
# 799.0
# block, trial =  1 95
# nan
# block, trial =  1 96
# 1138.0
# block, trial =  1 97
# 1018.0
# block, trial =  1 98
# 857.0
# block, trial =  1 99
# 945.0
# block, trial =  1 100
# 753.0
# block, trial =  1 101
# 765.0
# block, trial =  1 102
# 973.0
# block, trial =  1 103
# nan
# block, trial =  1 104
# nan
# block, trial =  1 105
# 1157.0
# block, trial =  1 106
# 1063.0
# block, trial =  1 107
# 1346.0
# block, trial =  1 108
# 850.0
# block, trial =  1 109
# 905.0
# block, trial =  1 110
# 917.0
# block, trial =  1 111
# 832.0
# block, trial =  1 112
# nan
# block, trial =  1 113
# nan
# block, trial =  1 114
# nan
# block, trial =  1 115
# 871.0
# block, trial =  1 116
# 1259.0
# block, trial =  1 117
# nan
# block, trial =  1 118
# 688.0
# block, trial =  1 119
# 666.0
# block, trial =  1 120
# 1311.0
# block, trial =  1 121
# 842.0
# block, trial =  1 122
# nan
# block, trial =  1 123
# 774.0
# block, trial =  1 124
# 656.0
# block, trial =  1 125
# 734.0
# block, trial =  1 126
# 951.0
# block, trial =  1 127
# 920.0
# block, trial =  1 128
# 942.0
# block, trial =  1 129
# 977.0
# block, trial =  1 130
# 810.0
# block, trial =  1 131
# 1153.0
# block, trial =  1 132
# 747.0
# block, trial =  1 133
# nan
# block, trial =  1 134
# 844.0
# block, trial =  1 135
# 847.0
# block, trial =  1 136
# nan
# block, trial =  1 137
# 953.0
# block, trial =  1 138
# 847.0
# block, trial =  1 139
# 617.0
# block, trial =  1 140
# 767.0
# block, trial =  1 141
# 841.0
# block, trial =  1 142
# 659.0
# block, trial =  1 143
# nan
# block, trial =  1 144
# 1060.0
# block, trial =  1 145
# nan
# block, trial =  1 146
# 637.0
# block, trial =  1 147
# 903.0
# block, trial =  1 148
# 1171.0
# block, trial =  1 149
# 756.0
# block, trial =  1 150
# 933.0
# block, trial =  1 151
# 802.0
# block, trial =  1 152
# 804.0
# block, trial =  1 153
# 1016.0
# block, trial =  1 154
# 845.0
# block, trial =  1 155
# nan
# block, trial =  1 156
# 1245.0
# block, trial =  1 157
# 1341.0
# block, trial =  1 158
# 759.0
# block, trial =  1 159
# nan
# block, trial =  1 160
# 1165.0
# block, trial =  1 161
# 1003.0
# block, trial =  1 162
# 395.0
# block, trial =  1 163
# nan
# block, trial =  1 164
# nan
# block, trial =  1 165
# 854.0
# block, trial =  1 166
# nan
# block, trial =  1 167
# nan
# block, trial =  1 168
# nan
# block, trial =  1 169
# 984.0
# block, trial =  1 170
# 1386.0
# block, trial =  1 171
# nan
# block, trial =  1 172
# 788.0
# block, trial =  1 173
# nan
# block, trial =  1 174
# nan
# block, trial =  1 175
# 761.0
# block, trial =  1 176
# 1330.0
# block, trial =  1 177
# nan
# block, trial =  1 178
# 728.0
# block, trial =  1 179
# nan
# block, trial =  1 180
# nan
# block, trial =  1 181
# nan
# block, trial =  1 182
# nan
# block, trial =  1 183
# 1019.0
# block, trial =  1 184
# 1386.0
# block, trial =  1 185
# 902.0
# block, trial =  1 186
# 680.0
# block, trial =  1 187
# 694.0
# block, trial =  1 188
# 1084.0
# block, trial =  1 189
# 838.0
# block, trial =  1 190
# 698.0
# block, trial =  1 191
# 1245.0
# block, trial =  1 192
# 761.0
# block, trial =  1 193
# 1223.0
# block, trial =  1 194
# 861.0
# block, trial =  1 195
# nan
# block, trial =  1 196
# 1262.0
# block, trial =  1 197
# 954.0
# block, trial =  1 198
# 748.0
# block, trial =  1 199
# 1203.0
# block, trial =  2 0
# 865.0
# block, trial =  2 1
# nan
# block, trial =  2 2
# 695.0
# block, trial =  2 3
# 997.0
# block, trial =  2 4
# nan
# block, trial =  2 5
# nan
# block, trial =  2 6
# 754.0
# block, trial =  2 7
# 1077.0
# block, trial =  2 8
# 795.0
# block, trial =  2 9
# 998.0
# block, trial =  2 10
# 414.0
# block, trial =  2 11
# 660.0
# block, trial =  2 12
# 928.0
# block, trial =  2 13
# nan
# block, trial =  2 14
# 743.0
# block, trial =  2 15
# 894.0
# block, trial =  2 16
# 543.0
# block, trial =  2 17
# 981.0
# block, trial =  2 18
# 734.0
# block, trial =  2 19
# 812.0
# block, trial =  2 20
# nan
# block, trial =  2 21
# 1066.0
# block, trial =  2 22
# 1236.0
# block, trial =  2 23
# 1284.0
# block, trial =  2 24
# 1086.0
# block, trial =  2 25
# 740.0
# block, trial =  2 26
# 750.0
# block, trial =  2 27
# 941.0
# block, trial =  2 28
# 938.0
# block, trial =  2 29
# 964.0
# block, trial =  2 30
# 1337.0
# block, trial =  2 31
# 739.0
# block, trial =  2 32
# 754.0
# block, trial =  2 33
# 1344.0
# block, trial =  2 34
# 974.0
# block, trial =  2 35
# 861.0
# block, trial =  2 36
# 1032.0
# block, trial =  2 37
# 1208.0
# block, trial =  2 38
# 918.0
# block, trial =  2 39
# 1016.0
# block, trial =  2 40
# 507.0
# block, trial =  2 41
# 993.0
# block, trial =  2 42
# 879.0
# block, trial =  2 43
# 907.0
# block, trial =  2 44
# 1342.0
# block, trial =  2 45
# 913.0
# block, trial =  2 46
# nan
# block, trial =  2 47
# 733.0
# block, trial =  2 48
# 1344.0
# block, trial =  2 49
# 750.0
# block, trial =  2 50
# 1115.0
# block, trial =  2 51
# nan
# block, trial =  2 52
# nan
# block, trial =  2 53
# 764.0
# block, trial =  2 54
# 743.0
# block, trial =  2 55
# 681.0
# block, trial =  2 56
# 1383.0
# block, trial =  2 57
# 406.0
# block, trial =  2 58
# 984.0
# block, trial =  2 59
# 1265.0
# block, trial =  2 60
# nan
# block, trial =  2 61
# nan
# block, trial =  2 62
# nan
# block, trial =  2 63
# nan
# block, trial =  2 64
# 1106.0
# block, trial =  2 65
# 820.0
# block, trial =  2 66
# 1310.0
# block, trial =  2 67
# nan
# block, trial =  2 68
# 660.0
# block, trial =  2 69
# 1295.0
# block, trial =  2 70
# 850.0
# block, trial =  2 71
# nan
# block, trial =  2 72
# 390.0
# block, trial =  2 73
# 1293.0
# block, trial =  2 74
# nan
# block, trial =  2 75
# 751.0
# block, trial =  2 76
# 1012.0
# block, trial =  2 77
# nan
# block, trial =  2 78
# 363.0
# block, trial =  2 79
# 844.0
# block, trial =  2 80
# nan
# block, trial =  2 81
# 829.0
# block, trial =  2 82
# nan
# block, trial =  2 83
# 766.0
# block, trial =  2 84
# 685.0
# block, trial =  2 85
# 821.0
# block, trial =  2 86
# 1094.0
# block, trial =  2 87
# nan
# block, trial =  2 88
# 974.0
# block, trial =  2 89
# nan
# block, trial =  2 90
# 643.0
# block, trial =  2 91
# nan
# block, trial =  2 92
# nan
# block, trial =  2 93
# 1118.0
# block, trial =  2 94
# 702.0
# block, trial =  2 95
# 1103.0
# block, trial =  2 96
# 826.0
# block, trial =  2 97
# 816.0
# block, trial =  2 98
# nan
# block, trial =  2 99
# nan
# block, trial =  2 100
# 994.0
# block, trial =  2 101
# 498.0
# block, trial =  2 102
# 1187.0
# block, trial =  2 103
# 1032.0
# block, trial =  2 104
# 725.0
# block, trial =  2 105
# 1385.0
# block, trial =  2 106
# 919.0
# block, trial =  2 107
# nan
# block, trial =  2 108
# nan
# block, trial =  2 109
# nan
# block, trial =  2 110
# 692.0
# block, trial =  2 111
# 789.0
# block, trial =  2 112
# 1364.0
# block, trial =  2 113
# nan
# block, trial =  2 114
# 630.0
# block, trial =  2 115
# 988.0
# block, trial =  2 116
# nan
# block, trial =  2 117
# 890.0
# block, trial =  2 118
# nan
# block, trial =  2 119
# 772.0
# block, trial =  2 120
# 1444.0
# block, trial =  2 121
# 1101.0
# block, trial =  2 122
# 884.0
# block, trial =  2 123
# nan
# block, trial =  2 124
# 1054.0
# block, trial =  2 125
# nan
# block, trial =  2 126
# 1007.0
# block, trial =  2 127
# nan
# block, trial =  2 128
# 874.0
# block, trial =  2 129
# 824.0
# block, trial =  2 130
# 908.0
# block, trial =  2 131
# 365.0
# block, trial =  2 132
# 1343.0
# block, trial =  2 133
# 701.0
# block, trial =  2 134
# 618.0
# block, trial =  2 135
# 469.0
# block, trial =  2 136
# 694.0
# block, trial =  2 137
# 806.0
# block, trial =  2 138
# nan
# block, trial =  2 139
# nan
# block, trial =  2 140
# 1077.0
# block, trial =  2 141
# 902.0
# block, trial =  2 142
# 1035.0
# block, trial =  2 143
# 1163.0
# block, trial =  2 144
# 715.0
# block, trial =  2 145
# 932.0
# block, trial =  2 146
# 1004.0
# block, trial =  2 147
# 751.0
# block, trial =  2 148
# 1008.0
# block, trial =  2 149
# 758.0
# block, trial =  2 150
# 1375.0
# block, trial =  2 151
# 719.0
# block, trial =  2 152
# 688.0
# block, trial =  2 153
# 1015.0
# block, trial =  2 154
# 739.0
# block, trial =  2 155
# 821.0
# block, trial =  2 156
# 1251.0
# block, trial =  2 157
# 935.0
# block, trial =  2 158
# 1043.0
# block, trial =  2 159
# nan
# block, trial =  2 160
# 1023.0
# block, trial =  2 161
# 723.0
# block, trial =  2 162
# 716.0
# block, trial =  2 163
# 528.0
# block, trial =  2 164
# 853.0
# block, trial =  2 165
# 1186.0
# block, trial =  2 166
# 810.0
# block, trial =  2 167
# 850.0
# block, trial =  2 168
# 381.0
# block, trial =  2 169
# 1242.0
# block, trial =  2 170
# 411.0
# block, trial =  2 171
# 903.0
# block, trial =  2 172
# 702.0
# block, trial =  2 173
# nan
# block, trial =  2 174
# 1048.0
# block, trial =  2 175
# nan
# block, trial =  2 176
# 810.0
# block, trial =  2 177
# nan
# block, trial =  2 178
# nan
# block, trial =  2 179
# 882.0
# block, trial =  2 180
# 1184.0
# block, trial =  2 181
# 566.0
# block, trial =  2 182
# 820.0
# block, trial =  2 183
# 805.0
# block, trial =  2 184
# 1254.0
# ...
# 501.0
# block, trial =  1 77
# nan
# block, trial =  1 78
# 1314.0
# block, trial =  1 79
# nan
# block, trial =  1 80
# nan
# block, trial =  1 81
# nan
# block, trial =  1 82
# nan
# block, trial =  1 83
# 404.0
# block, trial =  1 84
# 1067.0
# block, trial =  1 85
# nan
# block, trial =  1 86
# nan
# block, trial =  1 87
# nan
# block, trial =  1 88
# nan
# block, trial =  1 89
# 1831.0
# block, trial =  1 90
# nan
# block, trial =  1 91
# 1306.0
# block, trial =  1 92
# nan
# block, trial =  1 93
# 1614.0
# block, trial =  1 94
# 1810.0
# block, trial =  1 95
# 1486.0
# block, trial =  1 96
# nan
# block, trial =  1 97
# 711.0
# block, trial =  1 98
# nan
# block, trial =  1 99
# nan
# block, trial =  1 100
# 834.0
# block, trial =  1 101
# nan
# block, trial =  1 102
# 985.0
# block, trial =  1 103
# 1320.0
# block, trial =  1 104
# 1223.0
# block, trial =  1 105
# 1134.0
# block, trial =  1 106
# 1091.0
# block, trial =  1 107
# nan
# block, trial =  1 108
# nan
# block, trial =  1 109
# nan
# block, trial =  1 110
# 1350.0
# block, trial =  1 111
# nan
# block, trial =  1 112
# 1120.0
# block, trial =  1 113
# 1049.0
# block, trial =  1 114
# nan
# block, trial =  1 115
# nan
# block, trial =  1 116
# 1178.0
# block, trial =  1 117
# nan
# block, trial =  1 118
# nan
# block, trial =  1 119
# nan
# block, trial =  1 120
# 1098.0
# block, trial =  1 121
# 922.0
# block, trial =  1 122
# 859.0
# block, trial =  1 123
# nan
# block, trial =  1 124
# nan
# block, trial =  1 125
# nan
# block, trial =  1 126
# 1038.0
# block, trial =  1 127
# /Users/laurentperrinet/pool/ANR-REM/ANEMO/ANEMO/ANEMO.py:75: RuntimeWarning: Mean of empty slice
#   old_anti = np.nanmean(velocity_NAN[TargetOn-t_0-50:TargetOn-t_0+50])
# 933.0
# /usr/local/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# block, trial =  1 128
# nan
# block, trial =  1 129
# 358.0
# block, trial =  1 130
# nan
# block, trial =  1 131
# 1191.0
# block, trial =  1 132
# nan
# block, trial =  1 133
# 1187.0
# block, trial =  1 134
# nan
# block, trial =  1 135
# nan
# block, trial =  1 136
# nan
# block, trial =  1 137
# 2117.0
# block, trial =  1 138
# nan
# block, trial =  1 139
# nan
# block, trial =  1 140
# nan
# block, trial =  1 141
# 999.0
# block, trial =  1 142
# 832.0
# block, trial =  1 143
# nan
# block, trial =  1 144
# nan
# block, trial =  1 145
# nan
# block, trial =  1 146
# nan
# block, trial =  1 147
# nan
# block, trial =  1 148
# nan
# block, trial =  1 149
# nan
# block, trial =  1 150
# 1277.0
# block, trial =  1 151
# 774.0
# block, trial =  1 152
# nan
# block, trial =  1 153
# nan
# block, trial =  1 154
# 1151.0
# block, trial =  1 155
# nan
# block, trial =  1 156
# nan
# block, trial =  1 157
# 583.0
# block, trial =  1 158
# nan
# block, trial =  1 159
# nan
# block, trial =  1 160
# nan
# block, trial =  1 161
# nan
# block, trial =  1 162
# 1463.0
# block, trial =  1 163
# nan
# block, trial =  1 164
# 725.0
# block, trial =  1 165
# 889.0
# block, trial =  1 166
# nan
# block, trial =  1 167
# nan
# block, trial =  1 168
# nan
# block, trial =  1 169
# 1132.0
# block, trial =  1 170
# 136.0
# block, trial =  1 171
# nan
# block, trial =  1 172
# 2227.0
# block, trial =  1 173
# nan
# block, trial =  1 174
# 1026.0
# block, trial =  1 175
# 601.0
# block, trial =  1 176
# 838.0
# block, trial =  1 177
# nan
# block, trial =  1 178
# nan
# block, trial =  1 179
# 918.0
# block, trial =  1 180
# nan
# block, trial =  1 181
# 414.0
# block, trial =  1 182
# nan
# block, trial =  1 183
# 2482.0
# block, trial =  1 184
# nan
# block, trial =  1 185
# 435.0
# block, trial =  1 186
# nan
# block, trial =  1 187
# nan
# block, trial =  1 188
# nan
# block, trial =  1 189
# nan
# block, trial =  1 190
# 813.0
# block, trial =  1 191
# 956.0
# block, trial =  1 192
# nan
# block, trial =  1 193
# nan
# block, trial =  1 194
# 483.0
# block, trial =  1 195
# nan
# block, trial =  1 196
# nan
# block, trial =  1 197
# nan
# block, trial =  1 198
# 522.0
# block, trial =  1 199
# nan
# block, trial =  2 0
# 733.0
# block, trial =  2 1
# 867.0
# block, trial =  2 2
# nan
# block, trial =  2 3
# nan
# block, trial =  2 4
# nan
# block, trial =  2 5
# 131.0
# block, trial =  2 6
# nan
# block, trial =  2 7
# nan
# block, trial =  2 8
# 402.0
# block, trial =  2 9
# 645.0
# block, trial =  2 10
# 861.0
# block, trial =  2 11
# nan
# block, trial =  2 12
# 811.0
# block, trial =  2 13
# 1057.0
# block, trial =  2 14
# 1107.0
# block, trial =  2 15
# 1365.0
# block, trial =  2 16
# nan
# block, trial =  2 17
# nan
# block, trial =  2 18
# nan
# block, trial =  2 19
# 666.0
# block, trial =  2 20
# 584.0
# block, trial =  2 21
# nan
# block, trial =  2 22
# 882.0
# block, trial =  2 23
# nan
# block, trial =  2 24
# 1017.0
# block, trial =  2 25
# nan
# block, trial =  2 26
# nan
# block, trial =  2 27
# 790.0
# block, trial =  2 28
# nan
# block, trial =  2 29
# 622.0
# block, trial =  2 30
# nan
# block, trial =  2 31
# nan
# block, trial =  2 32
# 1191.0
# block, trial =  2 33
# 1056.0
# block, trial =  2 34
# 729.0
# block, trial =  2 35
# nan
# block, trial =  2 36
# nan
# block, trial =  2 37
# nan
# block, trial =  2 38
# nan
# block, trial =  2 39
# 789.0
# block, trial =  2 40
# 1066.0
# block, trial =  2 41
# nan
# block, trial =  2 42
# nan
# block, trial =  2 43
# nan
# block, trial =  2 44
# nan
# block, trial =  2 45
# nan
# block, trial =  2 46
# 1017.0
# block, trial =  2 47
# nan
# block, trial =  2 48
# nan
# block, trial =  2 49
# nan
# block, trial =  2 50
# nan
# block, trial =  2 51
# 1921.0
# block, trial =  2 52
# nan
# block, trial =  2 53
# nan
# block, trial =  2 54
# 703.0
# block, trial =  2 55
# nan
# block, trial =  2 56
# nan
# block, trial =  2 57
# nan
# block, trial =  2 58
# nan
# block, trial =  2 59
# nan
# block, trial =  2 60
# 1003.0
# block, trial =  2 61
# 433.0
# block, trial =  2 62
# nan
# block, trial =  2 63
# nan
# block, trial =  2 64
# nan
# block, trial =  2 65
# nan
# block, trial =  2 66
# nan
# block, trial =  2 67
# nan
# block, trial =  2 68
# nan
# block, trial =  2 69
# 1415.0
# block, trial =  2 70
# 1142.0
# block, trial =  2 71
# 1220.0
# block, trial =  2 72
# 1107.0
# block, trial =  2 73
# nan
# block, trial =  2 74
# 756.0
# block, trial =  2 75
# 1084.0
# block, trial =  2 76
# nan
# block, trial =  2 77
# 1071.0
# block, trial =  2 78
# nan
# block, trial =  2 79
# nan
# block, trial =  2 80
# 562.0
# block, trial =  2 81
# 1164.0
# block, trial =  2 82
# nan
# block, trial =  2 83
# nan
# block, trial =  2 84
# nan
# block, trial =  2 85
# 1132.0
# block, trial =  2 86
# 385.0
# block, trial =  2 87
# 1248.0
# block, trial =  2 88
# nan
# block, trial =  2 89
# nan
# block, trial =  2 90
# nan
# block, trial =  2 91
# nan
# block, trial =  2 92
# nan
# block, trial =  2 93
# 395.0
# block, trial =  2 94
# nan
# block, trial =  2 95
# nan
# block, trial =  2 96
# nan
# block, trial =  2 97
# nan
# block, trial =  2 98
# nan
# block, trial =  2 99
# nan
# block, trial =  2 100
# nan
# block, trial =  2 101
# nan
# block, trial =  2 102
# 393.0
# block, trial =  2 103
# nan
# block, trial =  2 104
# nan
# block, trial =  2 105
# 1361.0
# block, trial =  2 106
# 788.0
# block, trial =  2 107
# nan
# block, trial =  2 108
# 415.0
# block, trial =  2 109
# nan
# block, trial =  2 110
# nan
# block, trial =  2 111
# 1109.0
# block, trial =  2 112
# nan
# block, trial =  2 113
# 1156.0
# block, trial =  2 114
# nan
# block, trial =  2 115
# nan
# block, trial =  2 116
# 1329.0
# block, trial =  2 117
# 1533.0
# block, trial =  2 118
# nan
# block, trial =  2 119
# 1126.0
# block, trial =  2 120
# 1304.0
# block, trial =  2 121
# 1036.0
# block, trial =  2 122
# nan
# block, trial =  2 123
# 1275.0
# block, trial =  2 124
# nan
# block, trial =  2 125
# nan
# block, trial =  2 126
# nan
# block, trial =  2 127
# nan
# block, trial =  2 128
# 1352.0
# block, trial =  2 129
# 1195.0
# block, trial =  2 130
# 470.0
# block, trial =  2 131
# 400.0
# block, trial =  2 132
# 376.0
# block, trial =  2 133
# nan
# block, trial =  2 134
# nan
# block, trial =  2 135
# 967.0
# block, trial =  2 136
# 475.0
# block, trial =  2 137
# nan
# block, trial =  2 138
# nan
# block, trial =  2 139
# 918.0
# block, trial =  2 140
# nan
# block, trial =  2 141
# 900.0
# block, trial =  2 142
# 464.0
# block, trial =  2 143
# 813.0
# block, trial =  2 144
# 1033.0
# block, trial =  2 145
# 669.0
# block, trial =  2 146
# nan
# block, trial =  2 147
# 614.0
# block, trial =  2 148
# nan
# block, trial =  2 149
# nan
# block, trial =  2 150
# 742.0
# block, trial =  2 151
# 1057.0
# block, trial =  2 152
# 1016.0
# block, trial =  2 153
# 1492.0
# block, trial =  2 154
# nan
# block, trial =  2 155
# 1085.0
# block, trial =  2 156
# nan
# block, trial =  2 157
# nan
# block, trial =  2 158
# nan
# block, trial =  2 159
# nan
# block, trial =  2 160
# 1318.0
# block, trial =  2 161
# 847.0
# block, trial =  2 162
# nan
# block, trial =  2 163
# nan
# block, trial =  2 164
# nan
# block, trial =  2 165
# 544.0
# block, trial =  2 166
# nan
# block, trial =  2 167
# nan
# block, trial =  2 168
# nan
# block, trial =  2 169
# 382.0
# block, trial =  2 170
# nan
# block, trial =  2 171
# 1548.0
# block, trial =  2 172
# nan
# block, trial =  2 173
# 973.0
# block, trial =  2 174
# nan
# block, trial =  2 175
# 1077.0
# block, trial =  2 176
# nan
# block, trial =  2 177
# nan
# block, trial =  2 178
# 635.0
# block, trial =  2 179
# 954.0
# block, trial =  2 180
# nan
# block, trial =  2 181
# nan
# block, trial =  2 182
# nan
# block, trial =  2 183
# nan
# block, trial =  2 184
# nan
# block, trial =  2 185
# nan
# block, trial =  2 186
# nan
# block, trial =  2 187
# nan
# block, trial =  2 188
# nan
# block, trial =  2 189
# nan
# block, trial =  2 190
# nan
# block, trial =  2 191
# nan
# block, trial =  2 192
# 394.0
# block, trial =  2 193
# 1127.0
# block, trial =  2 194
# nan
# block, trial =  2 195
# 938.0
# block, trial =  2 196
# 1065.0
# block, trial =  2 197
# nan
# block, trial =  2 198
# nan
# block, trial =  2 199
# 1300.0
# FIN !!!
# Analysing subject FM
# block, trial =  0 0
# nan
# block, trial =  0 1
# nan
# block, trial =  0 2
# nan
# block, trial =  0 3
# nan
# block, trial =  0 4
# nan
# block, trial =  0 5
# nan
# block, trial =  0 6
# 1183.0
# block, trial =  0 7
# nan
# block, trial =  0 8
# 386.0
# block, trial =  0 9
# nan
# block, trial =  0 10
# 1046.0
# block, trial =  0 11
# nan
# block, trial =  0 12
# 1100.0
# block, trial =  0 13
# 788.0
# block, trial =  0 14
# nan
# block, trial =  0 15
# 1077.0
# block, trial =  0 16
# nan
# block, trial =  0 17
# 981.0
# block, trial =  0 18
# nan
# block, trial =  0 19
# nan
# block, trial =  0 20
# 711.0
# block, trial =  0 21
# nan
# block, trial =  0 22
# nan
# block, trial =  0 23
# 1252.0
# block, trial =  0 24
# 1024.0
# block, trial =  0 25
# 632.0
# block, trial =  0 26
# 1155.0
# block, trial =  0 27
# nan
# block, trial =  0 28
# nan
# block, trial =  0 29
# nan
# block, trial =  0 30
# 1087.0
# block, trial =  0 31
# 364.0
# block, trial =  0 32
# nan
# block, trial =  0 33
# 1321.0
# block, trial =  0 34
# 812.0
# block, trial =  0 35
# 792.0
# block, trial =  0 36
# 1030.0
# block, trial =  0 37
# nan
# block, trial =  0 38
# 941.0
# block, trial =  0 39
# nan
# block, trial =  0 40
# nan
# block, trial =  0 41
# 1289.0
# block, trial =  0 42
# nan
# block, trial =  0 43
# 999.0
# block, trial =  0 44
# 1103.0
# block, trial =  0 45
# nan
# block, trial =  0 46
# 610.0
# block, trial =  0 47
# 1137.0
# block, trial =  0 48
# nan
# block, trial =  0 49
# nan
# block, trial =  0 50
# nan
# block, trial =  0 51
# nan
# block, trial =  0 52
# nan
# block, trial =  0 53
# nan
# block, trial =  0 54
# nan
# block, trial =  0 55
# nan
# block, trial =  0 56
# nan
# block, trial =  0 57
# 924.0
# block, trial =  0 58
# nan
# block, trial =  0 59
# 714.0
# block, trial =  0 60
# nan
# block, trial =  0 61
# nan
# block, trial =  0 62
# 841.0
# block, trial =  0 63
# nan
# block, trial =  0 64
# 1294.0
# block, trial =  0 65
# nan
# block, trial =  0 66
# nan
# block, trial =  0 67
# 738.0
# block, trial =  0 68
# nan
# block, trial =  0 69
# 1215.0
# block, trial =  0 70
# nan
# block, trial =  0 71
# 1317.0
# block, trial =  0 72
# nan
# block, trial =  0 73
# 407.0
# block, trial =  0 74
# nan
# block, trial =  0 75
# nan
# block, trial =  0 76
# 1417.0
# block, trial =  0 77
# nan
# block, trial =  0 78
# 720.0
# block, trial =  0 79
# nan
# block, trial =  0 80
# 1303.0
# block, trial =  0 81
# nan
# block, trial =  0 82
# nan
# block, trial =  0 83
# nan
# block, trial =  0 84
# 1072.0
# block, trial =  0 85
# 688.0
# block, trial =  0 86
# nan
# block, trial =  0 87
# nan
# block, trial =  0 88
# nan
# block, trial =  0 89
# 553.0
# block, trial =  0 90
# 1144.0
# block, trial =  0 91
# 1263.0
# block, trial =  0 92
# 623.0
# block, trial =  0 93
# 722.0
# block, trial =  0 94
# 1097.0
# block, trial =  0 95
# 1006.0
# block, trial =  0 96
# 1005.0
# block, trial =  0 97
# 567.0
# block, trial =  0 98
# 379.0
# block, trial =  0 99
# 968.0
# block, trial =  0 100
# nan
# block, trial =  0 101
# 627.0
# block, trial =  0 102
# nan
# block, trial =  0 103
# nan
# block, trial =  0 104
# /Users/laurentperrinet/pool/ANR-REM/ANEMO/ANEMO/ANEMO.py:73: RuntimeWarning: Mean of empty slice
#   old_max = abs(np.nanmean(velocity_NAN[a1:b1]))
# nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-94edb444f0a8> in <module>()
#       7     from aSPEM import Analysis
#       8     e = Analysis(observer=observer, mode=mode)
# ----> 9     e.Fit(plot=True, fct_fit='fct_position')
#
# ~/pool/ANR-REM/AnticipatorySPEM/aSPEM.py in Fit(self, plot, fct_fit, fig_width, file_save, t_label, t_text, file_fig, list_events, sup, time_sup, param_fit, stop_recherche_misac, step_fit, avant, apres, do_whitening)
#     801                            fig_width=fig_width, t_label=t_label, t_text=t_text, file_fig=file_fig,
#     802                            param_fit=param_fit, stop_recherche_misac=stop_recherche_misac,
# --> 803                            step_fit=step_fit, fct_fit=fct_fit, avant=avant, apres=apres, do_whitening=do_whitening)
#     804
#     805         if file_save is None :
#
# ~/pool/ANR-REM/ANEMO/ANEMO/ANEMO.py in Fit(self, data, list_events, sup, time_sup, plot, fig_width, t_label, t_text, file_fig, param_fit, stop_recherche_misac, fct_fit, step_fit, avant, apres, do_whitening)
#     768                                              old_latence=old_latence, old_max=old_max, old_anti=old_anti,
#     769                                              TargetOn=arg.TargetOn, StimulusOf=arg.StimulusOf, saccades=saccades, sup=sup, time_sup=time_sup, step=step_fit,
# --> 770                                              fct_fit=fct_fit, avant=avant, apres=apres, do_whitening=do_whitening)
#     771                 ##################################################
#     772
#
# ~/pool/ANR-REM/ANEMO/ANEMO/ANEMO.py in Fit_trial(self, data_trial, trackertime, dir_target, fct_fit, data_x, param_fit, old_latence, old_max, old_anti, TargetOn, StimulusOf, saccades, sup, time_sup, avant, apres, do_whitening, step)
#     581                 out = model.fit(data_trial, params, x=np.arange(len(trackertime)), nan_policy='omit')
#     582             elif fct_fit=='fct_position' :
# --> 583                 out = model.fit(data_trial, params, x=np.arange(len(trackertime)), data_x=data_x, saccades=sacc, nan_policy='omit')
#     584
#     585             # make the other parameters vary now
#
# /usr/local/lib/python3.6/site-packages/lmfit/model.py in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, **kwargs)
#     871                              scale_covar=scale_covar, fcn_kws=kwargs,
#     872                              nan_policy=self.nan_policy, **fit_kws)
# --> 873         output.fit(data=data, weights=weights)
#     874         output.components = self.components
#     875         return output
#
# /usr/local/lib/python3.6/site-packages/lmfit/model.py in fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1215         self.userkws.update(kwargs)
#    1216         self.init_fit = self.model.eval(params=self.params, **self.userkws)
# -> 1217         _ret = self.minimize(method=self.method)
#    1218
#    1219         for attr in dir(_ret):
#
# /usr/local/lib/python3.6/site-packages/lmfit/minimizer.py in minimize(self, method, params, **kws)
#    1809                         val.lower().startswith(user_method)):
#    1810                     kwargs['method'] = val
# -> 1811         return function(**kwargs)
#    1812
#    1813
#
# /usr/local/lib/python3.6/site-packages/lmfit/minimizer.py in leastsq(self, params, **kws)
#    1362
#    1363         try:
# -> 1364             lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1365             _best, _cov, infodict, errmsg, ier = lsout
#    1366             result.residual = infodict['fvec']
#
# /usr/local/lib/python3.6/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     392         with _MINPACK_LOCK:
#     393             retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 394                                      gtol, maxfev, epsfcn, factor, diag)
#     395     else:
#     396         if col_deriv:
#
# ValueError: The array returned by a function changed size between calls
